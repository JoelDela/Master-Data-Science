# %% [markdown]
# ## Image Reconstruction

# %% [markdown]
# ### Problem statement
# Reconstruct the Image

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("../data/incomplete_smiley.csv")
df["color"]=df["color"].apply(lambda e: 0 if e=="black" else 1).astype(int)
df=df.dropna()

# %%
df.head()
# Out:
#    Unnamed: 0   x   y  color
# 0        1160  11  60      1
# 1        9945  99  45      1
# 2        7608  76   8      1
# 3        1828  18  28      1
# 4        7068  70  68      1

# %%
X=df[["x","y"]].values
y=df["color"].values

# %%
plt.scatter(X[:,0],X[:,1],c=y);
