# %% [markdown]
# # Introduction to Neural Networks and Deep Learning

# %% [markdown]
# ## What's the difference between Artificial Intelligence, Machine Learning and Deep Learning?
#
# **Artificial Intelligence** (AI) is a very old field of research. It started in the 1950s; at that time, the pioneers in AI were convinced that they could make machines think. The initial approach was attempting to model intellectual tasks, and program those tasks in computers. That is, in the beginning, AI was about people *hard-coding* problems that the machine tried to solve. A good example of an early AI program is computer chess. Early AI computer chess programs had **lots of rules pre-conceived by the program designers**. So although the term refers to "intelligence", these programs were not "intelligent", but just a sophisticated set of rules.
#
# * The term *neural network* was also born at that time. The initial idea was trying to mimic how a *neuron* works (or in fact, how it was thought a neuron worked when the term was coined) in the brain. As in the case of *Artificial Intelligence*, please do not be fooled by the terms. A *neural network* is just a way to compute approximation to functions. A powerful and useful way, true. But it is not any kind of "artificial brain", or anything like that.
#
# This approach is now obsolete. We now know that some tasks are so complex, that we will never be able to pre-design a system to have a good performance on those tasks. Take the example of the game of Go. Any program designed by humans to play Go was dull and could not compete against professional players. The game is so hard that is just impossible for us as humans to conceived a good Go computer player.
# * https://en.wikipedia.org/wiki/Go_(game)
#
# The modern approach to solve this kind of problems involves the use of data. This is what the *learning* part of *Deep Learning* (and *Machine Learning*) refers to. **Learning from data**. So, with this brief introduction, we can say that *Artificial Intelligence* is a broad concept that includes *Machine Learning*, that includes *Deep Learning*. *Artificial Intelligence* does not necessarily means learning from data, but Machine Learning does. And *Deep Learning* is just doing *Machine Learning* with neural networks.
#
# ![](imgs/01_ai_ml_dl.png)
#
# We will see during this course what *learning* means, and what is a *neural network*.
#
# In the case of the game of Go, all attempts to design a good Go computer player failed, until Google DeepMind created AlphaGo, a system that *learned* to play Go based on data from previous games. AlphaGo is an example that learning from data can provide computer systems that are superior to any system pre-conceived by humans.
# * Find out more about AlphaGo by watching this utterly interesting movie: https://www.alphagomovie.com/
#
# In this course, we will give our first steps on *Deep Learning* and *Neural Networks*, to start creating systems that perform complex tasks by learning from data. Instead of attempting to derive the rules by ourselves, those rules will be inferred by a neural network based on the data we provide:
#
# ![](imgs/02_rules_data.png)

# %% [markdown]
# # Deep Learning and Machine Learning: why is everyone now talking about Deep Learning?
#
# To create our system, we need data:
# * Input data points; e.g. images to recognize shapes inside the images.
# * Examples of expected output. The system will use these examples to learn from them. For the images above, we will need *labels* telling us what is in the image.
#
# The neural network will *learn* from this data. But in fact, what the network is doing is learning a *representation* of the data that makes the task much easier to solve.
#
# Let's see an example. We have the following input data (x,y coordinates for the points), and the labels of each item (the color of the point). We would like to obtain a model to separete the two classes of points:
#
# ![](imgs/03_points.png)
#
# How would you separate the points? In the current reference system, it can be a complex task. But if you change the reference system (*if you learn a new representation of the data*), the task becomes trivial:
#
# ![](imgs/04_representation.png)
#
# In Deep Learning, we learn **layers** of increasingly better representations. The **deep** in Deep Learning refers to the number of layers that we learn. Before Deep Learning, the models that we are going to see today were much shallower. The most typical form of the layer representations is **neural networks**. As we will see, **neural networks** are just chain of matrix operations -- arrays of 2 dimensions--, or more precisely, tensor operations, we will operate in dimensions higher than 2.
#
#
# * More about learning representations: https://www.bbvadata.com/not-deep-learning-learning-represent/

# %%
import numpy as np

# %%
x=np.array([1,2])
W=np.array([[-1,-2],[-1,5]])

b=np.array([3,-3])
layer=W.dot(x)+b

layer_with_activation=np.maximum(layer,0)
layer_with_activation,layer
# Out:
# (array([0, 6]), array([-2,  6]))

# %% [markdown]
# ## Neural Networks
#
# A neural network is just a stacked set of layers. Each layer is represented by a tensor, and it performs an affine transformation on each one of the layers.
# * A matrix is a 2D tensor
# * Affine transformation $\vec{y} = W\cdot\vec{x} + \vec{b}$, where $W$ is the weights tensor, $\vec{x}$ is the input data, $\vec{y}$ is the output data and $\vec{b}$ is called the bias
# * $W$ and $\vec{b}$ are model parameters that need to be found by training
#
# ![](imgs/05_nn.png)
#
# Note that this is a **linear operation**, therefore the result will be linear too. But the functions we want to learn are normally non-linear. How do we overcome this limiation? By using an **activation function**, that transforms the result from the linear operation. So, we actually do the following operation:
#
# $\vec{y} = f\left(W\cdot\vec{x} + \vec{b}\right)$
#
# There are several common activation functions, depending on the characteristics of the data and the kind of problem we want to solve. Here we will use the probably most often used activation function: **rectified linear unit**, or **relu** for friends:
#
# ![Relu plot](https://upload.wikimedia.org/wikipedia/commons/6/6c/Rectifier_and_softplus_functions.svg)
#
# (image extracted from https://en.wikipedia.org/wiki/Rectifier_(neural_networks))
#
# Relu will add the non-linearity that we need to learn arbitrary functions.
#
# We can achieve the same with many other activation functions. See the documentation of Keras for details on the available activation functions:
#  - https://keras.io/activations/
#
#
# Each layer learns a new representation of the input data, and after several layers, the representation will make it straightforward to solve the task (e.g. assiging a digit to an image of a digit).
#
# Until very recently, any attempt to train a deep neural network would not provide good results. Recent progresses (e.g. advances in hardware, new activation functions) make it possible to train very deep network, and therefore, solve problems that were unfeasible not long ago.
#
# ### Training process
#
# The parameters of the network are initially randomly assigned. Then after each pass of the network, that is, after each *epoch*, the predictions of the network is compared against the true values, applying a *loss function*. This score is used to update the parameters of the network, with a process called **backpropagation**.
# * Backpropagation is a complex process that involves calculating the gradient of the parameters of the network. For more details see: https://en.wikipedia.org/wiki/Backpropagation
# * See also this excellent and visual explanation of how backpropagation works: https://google-developers.appspot.com/machine-learning/crash-course/backprop-scroll/
#
# The training process is just an optimization process, that is normally done using a gradient descent-based algorithm. The values of gradients are computed using the backpropagation algorithm. Each epoch will make the loss score to be lower, and the predictions to be better.
#
# ![](imgs/06_optim.png)
#
# In practice, we have to fine tune the number of epochs (and other parameters), until we obtain a result that is good enough for our purpose. In fact, if the number of epochs is too high, our model may **overfit** the training data. In that case, it will perform worsely when the model is exposed to data that it  has not seen previously.
# * Fine tuning the number of epochs, and other parameters (e.g. the number and shape of the layers) is known as **hyperparameters optimization**, or **hyperparameters tuning**
# * The parameters of the model are the $W$ and $b$ values of each layer, and those are determined by training.
#
# ## Hyperparameters tuning
#
# In summary, when we are trying to obtain a deep learning model, the process that we will follow is:
# * Decide on the architecture of the network (number of layers, type of each layer, size of each layer)
# * Decide on the activation functions on each layer
# * Decide on the parameters related to the optimization process (e.g. learning rate)
# * Decide on the loss function that we will use
# * Decide on the metrics that we will use to evaluate the performance of the model
# * Decide on the training parameters (number of epochs, batch size)
# * Decide on how to split the data between training, validation and test sets.
#
# We obtain feedback for those decisions with the results of the training applied to the validation set. We train once, change some of the hyperparameters, train again, decide if that's better, and we keep going until we have found a model that is satisfactory enough for our purposes.
#
# After that, we finally evaluate the model on the test set.

# %% [markdown]
# ## Our first neural network
#
# Let's start with an easy example. We are going to produce some synthetic data, and will try to predict the function that generates the data. We will add some noise, to make the problem more difficult.
#
# The function we are going to try to predict is
#
# $\displaystyle y = 3*x + 2$

# %%
# %pylab inline
plt.style.use('seaborn-talk')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_metric(history, metric):
    history_dict = history.history
    values = history_dict[metric]
    if 'val_' + metric in history_dict.keys():  
        val_values = history_dict['val_' + metric]

    epochs = range(1, len(values) + 1)

    if 'val_' + metric in history_dict.keys():  
        plt.plot(epochs, val_values, label='Validation')
    plt.semilogy(epochs, values, label='Training')

    if 'val_' + metric in history_dict.keys():  
        plt.title('Training and validation %s' % metric)
    else:
        plt.title('Training %s' % metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()

    plt.show()

# %% [markdown]
# ### Preparar los datos

# %%
x_train = np.linspace(0, 100, 1000)
y_train = 3*x_train + 2

# %%
plot(x_train, y_train)

# %%
x_test = np.linspace(100.1, 110, 1000)
y_test = 3*x_test + 2

# %%
plt.plot(x_train,y_train)
plt.plot(x_test,y_test)
plt.show()

# %%
import tensorflow as tf

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
import tensorflow.keras as keras
from keras import layers

# %%
layers.Dense(units=64,activation='relu')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
from keras import Sequential

# %%
model=Sequential()

# %% [markdown]
# Un conjunto de datos x y un conjunto de etiquetas y.
#
# Montar 3 capas de 128, 64 y 32 neuronas

# %%
capa1=layers.Dense(units=128,activation='relu',input_shape=(1,))
model.add(capa1)
capa2=layers.Dense(units=64,activation='relu',input_shape=(1,))
model.add(capa2)
model.add(layers.Dense(units=32,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=1,activation='relu',input_shape=(1,)))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 128)               256
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 10,625
# Trainable params: 10,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Numero de params es igual a los pesos mas los biases

# %% [markdown]
# Ejemplo, capa 1:
#
# y= tamaño 128, W=tamaño 128x1, x = tamaño 1, b= tamaño 128
#
# capa 2:
#
# y= tamaño 64, W=tamaño 64x128, x = tamaño 128, b= tamaño 64
#
# capa 3:
#
# y= tamaño 32, W=tamaño 32x64, x = tamaño 64, b= tamaño 32
#
# capa 4:
#
# y= tamaño 1, W=tamaño 1x32, x = tamaño 32, b= tamaño 32

# %%
from keras import optimizers
from keras import losses
from keras import metrics

# %%
model.compile(optimizer=optimizers.RMSprop(), loss=losses.mse)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
h = model.fit(x_train,y_train,batch_size=100,epochs=20,validation_split=0.1)
# Out:
# Train on 900 samples, validate on 100 samples
# Epoch 1/20
# 900/900 [==============================] - 0s 40us/step - loss: 7.7203 - val_loss: 84.8440
# Epoch 2/20
# 900/900 [==============================] - 0s 37us/step - loss: 12.7935 - val_loss: 20.6051
# Epoch 3/20
# 900/900 [==============================] - 0s 35us/step - loss: 10.7343 - val_loss: 46.0239
# Epoch 4/20
# 900/900 [==============================] - 0s 34us/step - loss: 11.5937 - val_loss: 103.2795
# Epoch 5/20
# 900/900 [==============================] - 0s 42us/step - loss: 11.0691 - val_loss: 13.2581
# Epoch 6/20
# 900/900 [==============================] - 0s 29us/step - loss: 10.3469 - val_loss: 71.6500
# Epoch 7/20
# 900/900 [==============================] - 0s 28us/step - loss: 13.0525 - val_loss: 25.4267
# Epoch 8/20
# 900/900 [==============================] - 0s 39us/step - loss: 12.7992 - val_loss: 56.9135
# Epoch 9/20
# 900/900 [==============================] - 0s 30us/step - loss: 8.8065 - val_loss: 41.9947
# Epoch 10/20
# 900/900 [==============================] - 0s 28us/step - loss: 11.6999 - val_loss: 56.1046
# Epoch 11/20
# 900/900 [==============================] - 0s 28us/step - loss: 12.5808 - val_loss: 8.9191
# Epoch 12/20
# 900/900 [==============================] - 0s 29us/step - loss: 12.8550 - val_loss: 33.4880
# Epoch 13/20
# 900/900 [==============================] - 0s 29us/step - loss: 7.3381 - val_loss: 81.8581
# Epoch 14/20
# 900/900 [==============================] - 0s 31us/step - loss: 11.6383 - val_loss: 3.7899
# Epoch 15/20
# 900/900 [==============================] - 0s 32us/step - loss: 10.5616 - val_loss: 50.2185
# Epoch 16/20
# 900/900 [==============================] - 0s 28us/step - loss: 13.0349 - val_loss: 44.3112
# Epoch 17/20
# 900/900 [==============================] - 0s 37us/step - loss: 9.1930 - val_loss: 51.3082
# Epoch 18/20
# 900/900 [==============================] - 0s 41us/step - loss: 13.7375 - val_loss: 20.2758
# Epoch 19/20
# 900/900 [==============================] - 0s 37us/step - loss: 9.6527 - val_loss: 42.7502
# Epoch 20/20
# 900/900 [==============================] - 0s 34us/step - loss: 11.0136 - val_loss: 22.3120

# %%
plot_metric(h,'loss')

# %%
#Create model
model=Sequential()
# Build model
capa1=layers.Dense(units=128,activation='relu',input_shape=(1,))
model.add(capa1)
capa2=layers.Dense(units=64,activation='relu',input_shape=(1,))
model.add(capa2)
model.add(layers.Dense(units=32,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=1,activation='relu',input_shape=(1,)))

model.summary()
#Compile
model.compile(optimizer=optimizers.RMSprop(), loss=losses.mse, metrics=[metrics.mean_absolute_error])
#Fit
h = model.fit(x_train,y_train,batch_size=100,epochs=20,validation_split=0.1)
#Plot
plot_metric(h,'loss')
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_55 (Dense)             (None, 128)               256
# _________________________________________________________________
# dense_56 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_57 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_58 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 10,625
# Trainable params: 10,625
# Non-trainable params: 0
# _________________________________________________________________
# Train on 900 samples, validate on 100 samples
# Epoch 1/20
# 900/900 [==============================] - 1s 1ms/step - loss: 20220.2209 - mean_absolute_error: 123.4528 - val_loss: 51697.3008 - val_mean_absolute_error: 227.2670
# Epoch 2/20
# 900/900 [==============================] - 0s 39us/step - loss: 12165.0607 - mean_absolute_error: 95.2745 - val_loss: 26580.2441 - val_mean_absolute_error: 162.9606
# Epoch 3/20
# 900/900 [==============================] - 0s 34us/step - loss: 5374.9551 - mean_absolute_error: 62.9777 - val_loss: 8463.8154 - val_mean_absolute_error: 91.9577
# Epoch 4/20
# 900/900 [==============================] - 0s 31us/step - loss: 1307.1107 - mean_absolute_error: 30.4358 - val_loss: 952.0089 - val_mean_absolute_error: 30.8413
# Epoch 5/20
# 900/900 [==============================] - 0s 33us/step - loss: 99.7491 - mean_absolute_error: 7.8634 - val_loss: 9.4316 - val_mean_absolute_error: 3.0703
# Epoch 6/20
# 900/900 [==============================] - 0s 32us/step - loss: 0.7765 - mean_absolute_error: 0.6398 - val_loss: 0.2652 - val_mean_absolute_error: 0.5134
# Epoch 7/20
# 900/900 [==============================] - 0s 29us/step - loss: 0.1584 - mean_absolute_error: 0.3327 - val_loss: 0.1063 - val_mean_absolute_error: 0.3243
# Epoch 8/20
# 900/900 [==============================] - 0s 31us/step - loss: 0.1550 - mean_absolute_error: 0.3279 - val_loss: 0.1230 - val_mean_absolute_error: 0.3491
# Epoch 9/20
# 900/900 [==============================] - 0s 30us/step - loss: 0.4309 - mean_absolute_error: 0.5302 - val_loss: 3.1516 - val_mean_absolute_error: 1.7750
# Epoch 10/20
# 900/900 [==============================] - 0s 32us/step - loss: 9.3723 - mean_absolute_error: 2.4731 - val_loss: 77.7938 - val_mean_absolute_error: 8.8153
# Epoch 11/20
# 900/900 [==============================] - 0s 34us/step - loss: 6.8844 - mean_absolute_error: 2.0628 - val_loss: 18.0332 - val_mean_absolute_error: 4.2452
# Epoch 12/20
# 900/900 [==============================] - 0s 31us/step - loss: 17.1600 - mean_absolute_error: 3.5416 - val_loss: 28.1283 - val_mean_absolute_error: 5.3005
# Epoch 13/20
# 900/900 [==============================] - 0s 30us/step - loss: 5.0283 - mean_absolute_error: 1.8961 - val_loss: 45.2960 - val_mean_absolute_error: 6.7277
# Epoch 14/20
# 900/900 [==============================] - 0s 34us/step - loss: 10.9990 - mean_absolute_error: 2.6211 - val_loss: 39.5757 - val_mean_absolute_error: 6.2874
# Epoch 15/20
# 900/900 [==============================] - 0s 32us/step - loss: 14.3813 - mean_absolute_error: 3.2504 - val_loss: 10.5017 - val_mean_absolute_error: 3.2397
# Epoch 16/20
# 900/900 [==============================] - 0s 33us/step - loss: 10.1901 - mean_absolute_error: 2.5627 - val_loss: 58.1237 - val_mean_absolute_error: 7.6198
# Epoch 17/20
# 900/900 [==============================] - 0s 34us/step - loss: 9.7434 - mean_absolute_error: 2.6268 - val_loss: 35.7508 - val_mean_absolute_error: 5.9770
# Epoch 18/20
# 900/900 [==============================] - 0s 32us/step - loss: 14.6292 - mean_absolute_error: 3.1772 - val_loss: 22.1551 - val_mean_absolute_error: 4.7042
# Epoch 19/20
# 900/900 [==============================] - 0s 34us/step - loss: 3.5145 - mean_absolute_error: 1.5515 - val_loss: 58.7364 - val_mean_absolute_error: 7.6610
# Epoch 20/20
# 900/900 [==============================] - 0s 48us/step - loss: 13.9556 - mean_absolute_error: 3.1495 - val_loss: 49.8991 - val_mean_absolute_error: 7.0602

# %% [markdown]
# Normalizamos los datos

# %%
max_x,min_x=x_train.max(),x_train.min()
x_train_norm=(x_train-min_x)/(max_x-min_x)

max_y,min_y=y_train.max(),y_train.min()
y_train_norm=(y_train-min_y)/(max_y-min_y)

x_test_norm=(x_test-min_x)/(max_x-min_x)

y_test_norm=(y_test-min_y)/(max_y-min_y)

plot(x_train_norm,y_train_norm)
plot(x_test_norm,y_test_norm)

# %%
#Create model
model=Sequential()
# Build model
model.add(layers.Dense(units=32,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=16,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=1,activation='relu',input_shape=(1,)))

model.summary()
#Compile
m= model.compile(optimizer=optimizers.rmsprop(), loss=losses.mse, metrics=[metrics.mean_absolute_error])
#Fit
h = model.fit(x_train_norm,y_train_norm,batch_size=100,epochs=30,validation_split=0.1)
#Plot
plot_metric(h,'loss')
plot_metric(h,'mean_absolute_error')
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_72 (Dense)             (None, 32)                64
# _________________________________________________________________
# dense_73 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_74 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Train on 900 samples, validate on 100 samples
# Epoch 1/30
# 900/900 [==============================] - 1s 1ms/step - loss: 0.1892 - mean_absolute_error: 0.3665 - val_loss: 0.5034 - val_mean_absolute_error: 0.7091
# Epoch 2/30
# 900/900 [==============================] - 0s 34us/step - loss: 0.1052 - mean_absolute_error: 0.2648 - val_loss: 0.3204 - val_mean_absolute_error: 0.5657
# Epoch 3/30
# 900/900 [==============================] - 0s 31us/step - loss: 0.0580 - mean_absolute_error: 0.1937 - val_loss: 0.1926 - val_mean_absolute_error: 0.4384
# Epoch 4/30
# 900/900 [==============================] - 0s 31us/step - loss: 0.0305 - mean_absolute_error: 0.1415 - val_loss: 0.1092 - val_mean_absolute_error: 0.3300
# Epoch 5/30
# 900/900 [==============================] - 0s 31us/step - loss: 0.0164 - mean_absolute_error: 0.1076 - val_loss: 0.0586 - val_mean_absolute_error: 0.2416
# Epoch 6/30
# 900/900 [==============================] - 0s 33us/step - loss: 0.0100 - mean_absolute_error: 0.0863 - val_loss: 0.0345 - val_mean_absolute_error: 0.1853
# Epoch 7/30
# 900/900 [==============================] - 0s 30us/step - loss: 0.0065 - mean_absolute_error: 0.0696 - val_loss: 0.0208 - val_mean_absolute_error: 0.1439
# Epoch 8/30
# 900/900 [==============================] - 0s 30us/step - loss: 0.0039 - mean_absolute_error: 0.0536 - val_loss: 0.0121 - val_mean_absolute_error: 0.1094
# Epoch 9/30
# 900/900 [==============================] - 0s 28us/step - loss: 0.0021 - mean_absolute_error: 0.0388 - val_loss: 0.0060 - val_mean_absolute_error: 0.0772
# Epoch 10/30
# 900/900 [==============================] - 0s 34us/step - loss: 8.9269e-04 - mean_absolute_error: 0.0250 - val_loss: 0.0024 - val_mean_absolute_error: 0.0484
# Epoch 11/30
# 900/900 [==============================] - 0s 31us/step - loss: 2.6706e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0013 - val_mean_absolute_error: 0.0358
# Epoch 12/30
# 900/900 [==============================] - 0s 31us/step - loss: 1.1523e-04 - mean_absolute_error: 0.0092 - val_loss: 2.9252e-04 - val_mean_absolute_error: 0.0160
# Epoch 13/30
# 900/900 [==============================] - 0s 28us/step - loss: 7.6927e-05 - mean_absolute_error: 0.0080 - val_loss: 8.9870e-04 - val_mean_absolute_error: 0.0293
# Epoch 14/30
# 900/900 [==============================] - 0s 29us/step - loss: 7.8069e-05 - mean_absolute_error: 0.0081 - val_loss: 1.1653e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/30
# 900/900 [==============================] - 0s 41us/step - loss: 9.0946e-05 - mean_absolute_error: 0.0088 - val_loss: 7.6512e-04 - val_mean_absolute_error: 0.0270
# Epoch 16/30
# 900/900 [==============================] - 0s 31us/step - loss: 7.2577e-05 - mean_absolute_error: 0.0079 - val_loss: 1.3036e-04 - val_mean_absolute_error: 0.0098
# Epoch 17/30
# 900/900 [==============================] - 0s 29us/step - loss: 8.0689e-05 - mean_absolute_error: 0.0083 - val_loss: 9.2201e-04 - val_mean_absolute_error: 0.0297
# Epoch 18/30
# 900/900 [==============================] - 0s 33us/step - loss: 8.3347e-05 - mean_absolute_error: 0.0084 - val_loss: 1.3012e-04 - val_mean_absolute_error: 0.0098
# Epoch 19/30
# 900/900 [==============================] - 0s 36us/step - loss: 7.7284e-05 - mean_absolute_error: 0.0081 - val_loss: 7.8036e-04 - val_mean_absolute_error: 0.0273
# Epoch 20/30
# 900/900 [==============================] - 0s 31us/step - loss: 7.2015e-05 - mean_absolute_error: 0.0078 - val_loss: 1.1275e-04 - val_mean_absolute_error: 0.0089
# Epoch 21/30
# 900/900 [==============================] - 0s 29us/step - loss: 6.3367e-05 - mean_absolute_error: 0.0071 - val_loss: 8.2215e-04 - val_mean_absolute_error: 0.0280
# Epoch 22/30
# 900/900 [==============================] - 0s 32us/step - loss: 9.6520e-05 - mean_absolute_error: 0.0091 - val_loss: 1.5284e-04 - val_mean_absolute_error: 0.0109
# Epoch 23/30
# 900/900 [==============================] - 0s 30us/step - loss: 7.8001e-05 - mean_absolute_error: 0.0077 - val_loss: 0.0011 - val_mean_absolute_error: 0.0318
# Epoch 24/30
# 900/900 [==============================] - 0s 31us/step - loss: 4.8305e-05 - mean_absolute_error: 0.0061 - val_loss: 8.4276e-05 - val_mean_absolute_error: 0.0076
# Epoch 25/30
# 900/900 [==============================] - 0s 29us/step - loss: 1.0368e-04 - mean_absolute_error: 0.0095 - val_loss: 5.2184e-04 - val_mean_absolute_error: 0.0223
# Epoch 26/30
# 900/900 [==============================] - 0s 30us/step - loss: 4.6022e-05 - mean_absolute_error: 0.0060 - val_loss: 2.8112e-05 - val_mean_absolute_error: 0.0044
# Epoch 27/30
# 900/900 [==============================] - 0s 26us/step - loss: 8.6081e-05 - mean_absolute_error: 0.0085 - val_loss: 6.8145e-04 - val_mean_absolute_error: 0.0256
# Epoch 28/30
# 900/900 [==============================] - 0s 42us/step - loss: 7.6090e-05 - mean_absolute_error: 0.0081 - val_loss: 1.4122e-04 - val_mean_absolute_error: 0.0109
# Epoch 29/30
# 900/900 [==============================] - 0s 41us/step - loss: 7.3772e-05 - mean_absolute_error: 0.0078 - val_loss: 8.2426e-04 - val_mean_absolute_error: 0.0283
# Epoch 30/30
# 900/900 [==============================] - 0s 40us/step - loss: 6.1602e-05 - mean_absolute_error: 0.0072 - val_loss: 5.3746e-05 - val_mean_absolute_error: 0.0060

# %%
p=model.predict(x_test_norm)
plt.plot(x_train_norm,y_train_norm,'b')
plt.plot(x_test_norm, y_test_norm,'r')
plt.plot(x_test_norm,p,'--k')

# %% [markdown]
# Intentamos mejorarlo:

# %%
#Create model
model=Sequential()
# Build model
model.add(layers.Dense(units=64,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=32,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=16,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=1,activation='relu',input_shape=(1,)))

model.summary()
#Compile
model.compile(optimizer=optimizers.RMSprop(), loss=losses.mse, metrics=[metrics.mean_absolute_error])
#Fit
h = model.fit(x_train_norm,y_train_norm,batch_size=100,epochs=10,validation_split=0.1)
#Plot
plot_metric(h,'loss')
plot_metric(h,'mean_absolute_error')

p=model.predict(x_test_norm)
plt.plot(x_train_norm,y_train_norm,'b')
plt.plot(x_test_norm, y_test_norm,'r')
plt.plot(x_test_norm,p,'--k')
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_103 (Dense)            (None, 64)                128
# _________________________________________________________________
# dense_104 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_105 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_106 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 2,753
# Trainable params: 2,753
# Non-trainable params: 0
# _________________________________________________________________
# Train on 900 samples, validate on 100 samples
# Epoch 1/10
# 900/900 [==============================] - 2s 2ms/step - loss: 0.0375 - mean_absolute_error: 0.1428 - val_loss: 0.0185 - val_mean_absolute_error: 0.1358
# Epoch 2/10
# 900/900 [==============================] - 0s 48us/step - loss: 0.0029 - mean_absolute_error: 0.0459 - val_loss: 0.0052 - val_mean_absolute_error: 0.0718
# Epoch 3/10
# 900/900 [==============================] - 0s 43us/step - loss: 9.3241e-04 - mean_absolute_error: 0.0259 - val_loss: 0.0016 - val_mean_absolute_error: 0.0394
# Epoch 4/10
# 900/900 [==============================] - 0s 43us/step - loss: 1.5154e-04 - mean_absolute_error: 0.0100 - val_loss: 2.9931e-04 - val_mean_absolute_error: 0.0170
# Epoch 5/10
# 900/900 [==============================] - 0s 38us/step - loss: 2.1133e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0020 - val_mean_absolute_error: 0.0444
# Epoch 6/10
# 900/900 [==============================] - 0s 38us/step - loss: 1.9407e-04 - mean_absolute_error: 0.0126 - val_loss: 9.9003e-05 - val_mean_absolute_error: 0.0097
# Epoch 7/10
# 900/900 [==============================] - 0s 45us/step - loss: 3.0076e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0011 - val_mean_absolute_error: 0.0326
# Epoch 8/10
# 900/900 [==============================] - 0s 49us/step - loss: 3.0002e-04 - mean_absolute_error: 0.0160 - val_loss: 7.2013e-05 - val_mean_absolute_error: 0.0082
# Epoch 9/10
# 900/900 [==============================] - 0s 41us/step - loss: 2.9885e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0016 - val_mean_absolute_error: 0.0404
# Epoch 10/10
# 900/900 [==============================] - 0s 43us/step - loss: 2.2554e-04 - mean_absolute_error: 0.0139 - val_loss: 1.7158e-04 - val_mean_absolute_error: 0.0130

# %% [markdown]
# ### Now another more complex function
#
# Let's try to fit a parabollic function
#
# $\displaystyle y = -2x^2 + x + 1$

# %%
def f(x):
  return -2*x**2+x+1

# %%
x_train = np.linspace(-100, 100, 10000)
y_train = f(x_train)

x_test = np.linspace(100.1, 110, 10000)
y_test = f(x_test)

# %%
max_x,min_x=x_train.max(),x_train.min()
x_train_norm=(x_train-min_x)/(max_x-min_x)

max_y,min_y=y_train.max(),y_train.min()
y_train_norm=(y_train-min_y)/(max_y-min_y)

x_test_norm=(x_test-min_x)/(max_x-min_x)

y_test_norm=(y_test-min_y)/(max_y-min_y)

plot(x_train_norm,y_train_norm,'b')
plot(x_test_norm,y_test_norm,'r')

# %%
#Create model
model=Sequential()
# Build model
model.add(layers.Dense(units=32,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=16,activation='relu',input_shape=(1,)))
model.add(layers.Dense(units=1,activation=None,input_shape=(1,)))

model.summary()
#Compile
m= model.compile(optimizer=optimizers.rmsprop(), loss=losses.mse, metrics=[metrics.mean_absolute_error])
#Fit
h = model.fit(x_train_norm,y_train_norm,batch_size=100,epochs=30,validation_split=0.1)
#Plot
plot_metric(h,'loss')
plot_metric(h,'mean_absolute_error')

p=model.predict(x_test_norm)
p_train=model.predict(x_train_norm)

plt.plot(x_train_norm,y_train_norm,'b')
plt.plot(x_test_norm, y_test_norm,'r')
plt.plot(x_train_norm,p_train,'--g')
plt.plot(x_test_norm,p,'--k')
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_134 (Dense)            (None, 32)                64
# _________________________________________________________________
# dense_135 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_136 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/30
# 9000/9000 [==============================] - 2s 258us/step - loss: 0.1532 - mean_absolute_error: 0.3250 - val_loss: 0.6809 - val_mean_absolute_error: 0.8164
# Epoch 2/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 0.0512 - mean_absolute_error: 0.1943 - val_loss: 0.4927 - val_mean_absolute_error: 0.6932
# Epoch 3/30
# 9000/9000 [==============================] - 0s 30us/step - loss: 0.0382 - mean_absolute_error: 0.1671 - val_loss: 0.3540 - val_mean_absolute_error: 0.5864
# Epoch 4/30
# 9000/9000 [==============================] - 0s 31us/step - loss: 0.0220 - mean_absolute_error: 0.1244 - val_loss: 0.1971 - val_mean_absolute_error: 0.4352
# Epoch 5/30
# 9000/9000 [==============================] - 0s 33us/step - loss: 0.0078 - mean_absolute_error: 0.0688 - val_loss: 0.1103 - val_mean_absolute_error: 0.3239
# Epoch 6/30
# 9000/9000 [==============================] - 0s 31us/step - loss: 0.0024 - mean_absolute_error: 0.0357 - val_loss: 0.0572 - val_mean_absolute_error: 0.2311
# Epoch 7/30
# 9000/9000 [==============================] - 0s 37us/step - loss: 9.0779e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0346 - val_mean_absolute_error: 0.1784
# Epoch 8/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 4.8337e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0191 - val_mean_absolute_error: 0.1301
# Epoch 9/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 3.5173e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0190 - val_mean_absolute_error: 0.1308
# Epoch 10/30
# 9000/9000 [==============================] - 0s 34us/step - loss: 2.6397e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0240 - val_mean_absolute_error: 0.1492
# Epoch 11/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 2.4209e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0129 - val_mean_absolute_error: 0.1070
# Epoch 12/30
# 9000/9000 [==============================] - 0s 34us/step - loss: 2.3663e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0140 - val_mean_absolute_error: 0.1123
# Epoch 13/30
# 9000/9000 [==============================] - 0s 27us/step - loss: 2.3793e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0110 - val_mean_absolute_error: 0.0988
# Epoch 14/30
# 9000/9000 [==============================] - 0s 29us/step - loss: 2.0636e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0055 - val_mean_absolute_error: 0.0658
# Epoch 15/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 2.0783e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0034 - val_mean_absolute_error: 0.0481
# Epoch 16/30
# 9000/9000 [==============================] - 0s 38us/step - loss: 2.1629e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0028 - val_mean_absolute_error: 0.0425
# Epoch 17/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 2.0828e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0048 - val_mean_absolute_error: 0.0615
# Epoch 18/30
# 9000/9000 [==============================] - 0s 30us/step - loss: 2.0685e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361
# Epoch 19/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.1057e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0030 - val_mean_absolute_error: 0.0459
# Epoch 20/30
# 9000/9000 [==============================] - 0s 37us/step - loss: 2.0388e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 21/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.0593e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0024 - val_mean_absolute_error: 0.0392
# Epoch 22/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 2.0617e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0032 - val_mean_absolute_error: 0.0486
# Epoch 23/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.0232e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0028 - val_mean_absolute_error: 0.0446
# Epoch 24/30
# 9000/9000 [==============================] - 0s 29us/step - loss: 2.0056e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0032 - val_mean_absolute_error: 0.0489
# Epoch 25/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 1.9455e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0022 - val_mean_absolute_error: 0.0379
# Epoch 26/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 1.9452e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 27/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 2.0164e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0025 - val_mean_absolute_error: 0.0412
# Epoch 28/30
# 9000/9000 [==============================] - 0s 29us/step - loss: 1.9777e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0020 - val_mean_absolute_error: 0.0363
# Epoch 29/30
# 9000/9000 [==============================] - 0s 34us/step - loss: 1.8802e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 30/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.0251e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0017 - val_mean_absolute_error: 0.0328

# %%
#Create model
model=Sequential()
# Build model
model.add(layers.Dense(units=24,activation='elu',input_shape=(1,)))
model.add(layers.Dense(units=12,activation='elu',input_shape=(1,)))
model.add(layers.Dense(units=1,activation=None,input_shape=(1,)))

model.summary()
#Compile
m= model.compile(optimizer=optimizers.rmsprop(), loss=losses.mse, metrics=[metrics.mean_absolute_error])
#Fit
h = model.fit(x_train_norm,y_train_norm,batch_size=100,epochs=30)
#Plot
plot_metric(h,'loss')
plot_metric(h,'mean_absolute_error')

p=model.predict(x_test_norm)
p_train=model.predict(x_train_norm)

plt.plot(x_train_norm,y_train_norm,'b')
plt.plot(x_test_norm, y_test_norm,'r')
plt.plot(x_train_norm,p_train,'--g')
plt.plot(x_test_norm,p,'--k')
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_209 (Dense)            (None, 24)                48
# _________________________________________________________________
# dense_210 (Dense)            (None, 12)                300
# _________________________________________________________________
# dense_211 (Dense)            (None, 1)                 13
# =================================================================
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 10000/10000 [==============================] - 3s 289us/step - loss: 0.1269 - mean_absolute_error: 0.2967
# Epoch 2/30
# 10000/10000 [==============================] - 0s 32us/step - loss: 0.0778 - mean_absolute_error: 0.2395
# Epoch 3/30
# 10000/10000 [==============================] - 0s 30us/step - loss: 0.0645 - mean_absolute_error: 0.2175
# Epoch 4/30
# 10000/10000 [==============================] - 0s 29us/step - loss: 0.0403 - mean_absolute_error: 0.1694
# Epoch 5/30
# 10000/10000 [==============================] - 0s 33us/step - loss: 0.0131 - mean_absolute_error: 0.0883
# Epoch 6/30
# 10000/10000 [==============================] - 0s 35us/step - loss: 0.0032 - mean_absolute_error: 0.0422
# Epoch 7/30
# 10000/10000 [==============================] - 0s 40us/step - loss: 0.0022 - mean_absolute_error: 0.0367
# Epoch 8/30
# 10000/10000 [==============================] - 0s 35us/step - loss: 0.0018 - mean_absolute_error: 0.0342
# Epoch 9/30
# 10000/10000 [==============================] - 0s 36us/step - loss: 0.0016 - mean_absolute_error: 0.0326
# Epoch 10/30
# 10000/10000 [==============================] - 0s 32us/step - loss: 0.0015 - mean_absolute_error: 0.0318
# Epoch 11/30
# 10000/10000 [==============================] - 0s 36us/step - loss: 0.0014 - mean_absolute_error: 0.0306
# Epoch 12/30
# 10000/10000 [==============================] - 0s 40us/step - loss: 0.0013 - mean_absolute_error: 0.0294
# Epoch 13/30
# 10000/10000 [==============================] - 0s 37us/step - loss: 0.0013 - mean_absolute_error: 0.0285
# Epoch 14/30
# 10000/10000 [==============================] - 0s 31us/step - loss: 0.0011 - mean_absolute_error: 0.0270
# Epoch 15/30
# 10000/10000 [==============================] - 0s 38us/step - loss: 0.0011 - mean_absolute_error: 0.0261
# Epoch 16/30
# 10000/10000 [==============================] - 0s 40us/step - loss: 9.9873e-04 - mean_absolute_error: 0.0250
# Epoch 17/30
# 10000/10000 [==============================] - 0s 33us/step - loss: 9.0334e-04 - mean_absolute_error: 0.0236
# Epoch 18/30
# 10000/10000 [==============================] - 0s 30us/step - loss: 8.6052e-04 - mean_absolute_error: 0.0229
# Epoch 19/30
# 10000/10000 [==============================] - 0s 31us/step - loss: 7.8389e-04 - mean_absolute_error: 0.0220
# Epoch 20/30
# 10000/10000 [==============================] - 0s 31us/step - loss: 7.3767e-04 - mean_absolute_error: 0.0215
# Epoch 21/30
# 10000/10000 [==============================] - 0s 35us/step - loss: 6.9920e-04 - mean_absolute_error: 0.0207
# Epoch 22/30
# 10000/10000 [==============================] - 0s 29us/step - loss: 6.5363e-04 - mean_absolute_error: 0.0203
# Epoch 23/30
# 10000/10000 [==============================] - 0s 32us/step - loss: 6.0190e-04 - mean_absolute_error: 0.0200
# Epoch 24/30
# 10000/10000 [==============================] - 0s 31us/step - loss: 5.7590e-04 - mean_absolute_error: 0.0192
# Epoch 25/30
# 10000/10000 [==============================] - 0s 31us/step - loss: 5.7364e-04 - mean_absolute_error: 0.0202
# Epoch 26/30
# 10000/10000 [==============================] - 0s 31us/step - loss: 5.3495e-04 - mean_absolute_error: 0.0184
# Epoch 27/30
# 10000/10000 [==============================] - 0s 34us/step - loss: 5.3188e-04 - mean_absolute_error: 0.0200
# Epoch 28/30
# 10000/10000 [==============================] - 0s 31us/step - loss: 5.0971e-04 - mean_absolute_error: 0.0192
# Epoch 29/30
# 10000/10000 [==============================] - 0s 34us/step - loss: 5.1126e-04 - mean_absolute_error: 0.0196
# Epoch 30/30
# 10000/10000 [==============================] - 0s 37us/step - loss: 4.8409e-04 - mean_absolute_error: 0.0191

# %% [markdown]
# ### And now even a more complex one
#
# Let's try to predict now this function:
#
# $\displaystyle y = \cos(x)$

# %%
def f(x):
  return np.cos(x)

# %%
x_train = np.linspace(-100, 100, 10000)
y_train = f(x_train)

x_test = np.linspace(100.1, 110, 10000)
y_test = f(x_test)

# %%
max_x,min_x=x_train.max(),x_train.min()
x_train_norm=(x_train-min_x)/(max_x-min_x)

max_y,min_y=y_train.max(),y_train.min()
y_train_norm=(y_train-min_y)/(max_y-min_y)

x_test_norm=(x_test-min_x)/(max_x-min_x)

y_test_norm=(y_test-min_y)/(max_y-min_y)

plot(x_train_norm,y_train_norm,'b')
plot(x_test_norm,y_test_norm,'r')

# %%
#Create model
model=Sequential()
# Build model
model.add(layers.Dense(units=24,activation='elu',input_shape=(1,)))
model.add(layers.Dense(units=12,activation='elu',input_shape=(1,)))
model.add(layers.Dense(units=1,activation=None,input_shape=(1,)))

model.summary()
#Compile
m= model.compile(optimizer=optimizers.rmsprop(), loss=losses.mse, metrics=[metrics.mean_absolute_error])
#Fit
h = model.fit(x_train_norm,y_train_norm,batch_size=100,epochs=30)
#Plot
plot_metric(h,'loss')
plot_metric(h,'mean_absolute_error')

p=model.predict(x_test_norm)
p_train=model.predict(x_train_norm)

plt.plot(x_train_norm,y_train_norm,'b')
plt.plot(x_test_norm, y_test_norm,'r')
plt.plot(x_train_norm,p_train,'--g')
plt.plot(x_test_norm,p,'--k')
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_134 (Dense)            (None, 32)                64
# _________________________________________________________________
# dense_135 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_136 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/30
# 9000/9000 [==============================] - 2s 258us/step - loss: 0.1532 - mean_absolute_error: 0.3250 - val_loss: 0.6809 - val_mean_absolute_error: 0.8164
# Epoch 2/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 0.0512 - mean_absolute_error: 0.1943 - val_loss: 0.4927 - val_mean_absolute_error: 0.6932
# Epoch 3/30
# 9000/9000 [==============================] - 0s 30us/step - loss: 0.0382 - mean_absolute_error: 0.1671 - val_loss: 0.3540 - val_mean_absolute_error: 0.5864
# Epoch 4/30
# 9000/9000 [==============================] - 0s 31us/step - loss: 0.0220 - mean_absolute_error: 0.1244 - val_loss: 0.1971 - val_mean_absolute_error: 0.4352
# Epoch 5/30
# 9000/9000 [==============================] - 0s 33us/step - loss: 0.0078 - mean_absolute_error: 0.0688 - val_loss: 0.1103 - val_mean_absolute_error: 0.3239
# Epoch 6/30
# 9000/9000 [==============================] - 0s 31us/step - loss: 0.0024 - mean_absolute_error: 0.0357 - val_loss: 0.0572 - val_mean_absolute_error: 0.2311
# Epoch 7/30
# 9000/9000 [==============================] - 0s 37us/step - loss: 9.0779e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0346 - val_mean_absolute_error: 0.1784
# Epoch 8/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 4.8337e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0191 - val_mean_absolute_error: 0.1301
# Epoch 9/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 3.5173e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0190 - val_mean_absolute_error: 0.1308
# Epoch 10/30
# 9000/9000 [==============================] - 0s 34us/step - loss: 2.6397e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0240 - val_mean_absolute_error: 0.1492
# Epoch 11/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 2.4209e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0129 - val_mean_absolute_error: 0.1070
# Epoch 12/30
# 9000/9000 [==============================] - 0s 34us/step - loss: 2.3663e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0140 - val_mean_absolute_error: 0.1123
# Epoch 13/30
# 9000/9000 [==============================] - 0s 27us/step - loss: 2.3793e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0110 - val_mean_absolute_error: 0.0988
# Epoch 14/30
# 9000/9000 [==============================] - 0s 29us/step - loss: 2.0636e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0055 - val_mean_absolute_error: 0.0658
# Epoch 15/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 2.0783e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0034 - val_mean_absolute_error: 0.0481
# Epoch 16/30
# 9000/9000 [==============================] - 0s 38us/step - loss: 2.1629e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0028 - val_mean_absolute_error: 0.0425
# Epoch 17/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 2.0828e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0048 - val_mean_absolute_error: 0.0615
# Epoch 18/30
# 9000/9000 [==============================] - 0s 30us/step - loss: 2.0685e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361
# Epoch 19/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.1057e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0030 - val_mean_absolute_error: 0.0459
# Epoch 20/30
# 9000/9000 [==============================] - 0s 37us/step - loss: 2.0388e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 21/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.0593e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0024 - val_mean_absolute_error: 0.0392
# Epoch 22/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 2.0617e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0032 - val_mean_absolute_error: 0.0486
# Epoch 23/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.0232e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0028 - val_mean_absolute_error: 0.0446
# Epoch 24/30
# 9000/9000 [==============================] - 0s 29us/step - loss: 2.0056e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0032 - val_mean_absolute_error: 0.0489
# Epoch 25/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 1.9455e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0022 - val_mean_absolute_error: 0.0379
# Epoch 26/30
# 9000/9000 [==============================] - 0s 36us/step - loss: 1.9452e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 27/30
# 9000/9000 [==============================] - 0s 32us/step - loss: 2.0164e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0025 - val_mean_absolute_error: 0.0412
# Epoch 28/30
# 9000/9000 [==============================] - 0s 29us/step - loss: 1.9777e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0020 - val_mean_absolute_error: 0.0363
# Epoch 29/30
# 9000/9000 [==============================] - 0s 34us/step - loss: 1.8802e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 30/30
# 9000/9000 [==============================] - 0s 35us/step - loss: 2.0251e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0017 - val_mean_absolute_error: 0.0328
