# %%
# !pip install -U spacy

# %%
# !python -m spacy download es

# %%
import spacy

# %%
nlp = spacy.load('es')

# %%
doc = nlp(u'Madrid es la capital de España y de la Comunidad de Madrid.')

# %%
for token in doc:
  print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
# Out:
# Madrid Madrid PROPN PROPN___ nsubj Xxxxx True False
# es ser AUX AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin cop xx True True
# la lo DET DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art det xx True True
# capital capital NOUN NOUN__Gender=Fem|Number=Sing ROOT xxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# España España PROPN PROPN___ nmod Xxxxx True False
# y y CONJ CCONJ___ cc x True False
# de de ADP ADP__AdpType=Prep case xx True True
# la lo DET DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art det xx True True
# Comunidad Comunidad PROPN PROPN___ conj Xxxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# Madrid Madrid PROPN PROPN___ flat Xxxxx True False
# . . PUNCT PUNCT__PunctType=Peri punct . False False

# %%
from spacy import displacy

# %%
doc = nlp(u'Madrid es la capital de España y de la Comunidad de Madrid.')

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2150" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Madrid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# ...

# %%
doc2 = nlp(u'Madrid es la capital de España y de la Comunidad de Madrid.')

# %%
for ent in doc2.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Madrid 0 6 LOC
# España 24 30 LOC
# Comunidad de Madrid 39 58 LOC

# %%
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Madrid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  es la capital de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     España
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y de la
# ...
