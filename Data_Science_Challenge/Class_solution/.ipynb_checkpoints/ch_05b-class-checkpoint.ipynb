# %% [markdown]
# ## Web Service

# %% [raw]
# http://flask.pocoo.org/docs/0.10/quickstart/

# %%
import pandas as pd

# %%
pd.read_json('http://127.0.0.1:5000/ret_number/100')
# Out:
#    arr_port    pax                                        AirportName
# 0       LHR  88809                            London Heathrow Airport
# 1       MCO  70930                      Orlando International Airport
# 10      ORD  53200               Chicago O'Hare International Airport
# 11      FCO  45120                Leonardo da Vinci–Fiumicino Airport
# 12      IST  43850                                   Istanbul Airport
# 13      DFW  42420            Dallas/Fort Worth International Airport
# 14      CUN  42000                       Cancún International Airport
# 15      MAD  41410               Adolfo Suárez Madrid–Barajas Airport
# 16      BCN  41200                          Barcelona–El Prat Airport
# 17      LGA  40712                                 La Guardia Airport
# 18      ATL  39780   Hartsfield-Jackson Atlanta International Airport
# 19      EWR  36890               Newark Liberty International Airport
# ...
