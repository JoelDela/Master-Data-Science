# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
df = pd.read_csv('Boston.csv')

def extract_samples(gender,year):
    return df[(df["YEAR"]==year)&(df["GENDER"]==gender)]["TIMES"].values

def extract_top_samples(gender,year):
    return sorted(df[(df["TIMES"]>7200)&(df["YEAR"]==year)&(df["GENDER"]==gender)]["TIMES"].values)[:100]

# %%
samples = extract_samples("M",2007)

# %%
len(samples)
# Out:
# 12387

# %%
plt.hist(samples,bins=100)
plt.axvline(x=7200,c="red")
plt.show()

# %%
a = np.array([0,1,2])
a>1
# Out:
# array([False, False,  True])

# %%
samples_filtrado=samples[samples>7200]

# %%
plt.hist(samples_filtrado,bins=100)
plt.axvline(x=7200,c="red")
plt.show()

# %%
len(samples[samples<7200])
# Out:
# 12

# %%
print(np.mean(samples))
print(np.var(samples))
# Out:
# 13605.268910955034
# 5534321.679281312

# %%
years = df["YEAR"].unique()

# %%
samples=extract_top_samples("M",2007)

# %%
samples[:10]
# Out:
# [7378, 8053, 8073, 8087, 8105, 8106, 8164, 8168, 8201, 8224]

# %%
for year in [1931,1951,1971,1995,2015]:
    s = extract_top_samples("M",year)
    print (np.mean(s))
    print (np.var(s))
# Out:
# 11858.75
# 961796.4875
# 10653.442307692309
# 739586.2851331362
# 9350.51
# 154092.06990000003
# 8505.82
# 255079.1076
# 8733.62
# 144743.4756

# %%
# Let's make charts
means = [np.mean(extract_top_samples("M",year)) for year in years]

# %%
plt.plot(years,means)

# %%
varis = [np.var(extract_top_samples("M",year)) for year in years]

# %%
plt.plot(years,varis)
