# %% [markdown]
# # Visualization with Python
#
#
#
# <img src="https://www.python.org/static/img/python-logo.png" alt="yogen" style="width: 200px; float: right;"/>
# <br>
# <br>
# <br>
# <img src="http://yogen.io/assets/logo.svg" alt="yogen" style="width: 200px; float: right;"/>

# %% [markdown]
# # `matplotlib`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')

# %% [markdown]
# ## Matplotlib basic plotting
#
# A MATLAB-like plotting framework: [`pyplot`](https://matplotlib.org/api/pyplot_api.html).
#
# Also known as the "state-machine environment" because we can call methods of a global state machine and they will affect the appropiate objects.

# %% [markdown]
# ### Lines

# %%
plt.plot([0,1,2,3,4,5],[0,1,4,9,16,25])

# %%
xs=np.linspace(0.01,10)
ys=np.log(xs)

plt.plot(xs,ys)

# %% [markdown]
# #### Exercise
#
# Plot the logistic function
#
#
# $$f(x) = \frac{e^x}{1 + e^x}$$
#
# Between -7 and 7
#
# Esta regresión se utiliza para convertir valores a un rango entre 0 y 1

# %%
x=np.linspace(-7,7)   #Con linspace especificamos el número de valores que queremos, además que incluye ambos extremos
plt.plot(x,np.exp(x)/(1+np.exp(x)),'r')

# %%
x=np.arange(-7,7,0.2)   #Con arange especificas el paso que quieres entre cada punto y no inluye el extremo derecho
plt.scatter(x,np.exp(x)/(1+np.exp(x)))

# %% [markdown]
# ### Scatter plots

# %%
xs = np.random.randn(240,240,3)
plt.imshow(xs)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
xs=np.random.randn(50)*30+50
ys=2*xs+20

plt.scatter(xs,ys)

# %% [markdown]
# Here we are using a random noise ("jitter"
# ) added over the (perfectly following $f(x) = 2x + 20$) Y2 Series in order to get some noisier, more real-looking generated data.

# %%
xs=np.random.randn(50)*30+50
ys=2*xs+20+np.random.randn(50)*30

plt.scatter(xs,ys)

# %% [markdown]
# This is what happens if you make a line plot of unsorted data:

# %%
xs=np.random.randn(50)*30+50
ys=2*xs+20+np.random.randn(50)*30

plt.plot(xs,ys)

# %% [markdown]
# ### Bar plots
#
# Do not confuse with histograms (where the variables are continous)

# %%
plt.bar(range(3),[7,2,3]) #Las variables son discretas
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(range(3),[7,2,3])
plt.xticks(range(3),['x','y','z'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fd9a6d24410>,
#   <matplotlib.axis.XTick at 0x7fd9a6e125d0>,
#   <matplotlib.axis.XTick at 0x7fd9a6e12610>],
#  <a list of 3 Text xticklabel objects>)

# %% [markdown]
# ## The object-oriented interface
#
# Essential for finer control.
#
# The recommended procedure is to use pyplot to create figures and the object-oriented interface for plotting.
#
# We need to know the somewhat confusing [matplotlib terminology](http://matplotlib.org/faq/usage_faq.html#parts-of-a-figure)

# %% [markdown]
# ![Anatomy of a Matplotlib Figure](http://matplotlib.org/_images/anatomy1.png)

# %% [markdown]
# #### Figure
#
# A whole figure which may contain several Axes. It communicates with the `Canvas` for us.
#
# #### Axes vs Axis
#
# An `Axes` (yes, it looks like a plural noun but it's not, necessarily) is a single panel of a figure. An `Axes` contains generally 2, but sometimes 3, `Axis`. It is the object type we'll spend most time interacting with.
#
# `Axis` objects represent the lines in the x and y (and z in the case of 3D plots) dimensions. With them you can control ticks and ticklabels.

# %% [markdown]
# #### Artists
#
# There are two types of Artists: primitives and containers. The primitives represent the standard graphical objects we want to paint onto our canvas: Line2D, Rectangle, Text, AxesImage, etc., and the containers are places to put them (Axis, Axes and Figure).
#
# https://matplotlib.org/users/artists.html

# %% [markdown]
# ### Interlude: the recommended interface for our plotting functions
#
# From [the matplotlib FAQ](http://matplotlib.org/faq/usage_faq.html):
#
# ```python
# def my_plotter(ax, data1, data2, param_dict):
#     """
#     A helper function to make a graph
#
#     Parameters
#     ----------
#     ax : Axes
#         The axes to draw to
#
#     data1 : array
#        The x data
#
#     data2 : array
#        The y data
#
#     param_dict : dict
#        Dictionary of kwargs to pass to ax.plot
#
#     Returns
#     -------
#     out : list
#         list of artists added
#     """
#
#     out = ax.plot(data1, data2, **param_dict)
#     return out
# ```

# %% [markdown]
# ## `add_axes()`, `add_subplot`, and `subplots()`
#
# We can add Axes to a Figure by calling its add_axes method.
#
# A subplot is just an Axes that we place within an imaginary grid.
#
# For even finer control we can use [GridSpec](http://matplotlib.org/api/gridspec_api.html)

# %% [markdown]
# ### `add_axes()`
#
# See https://matplotlib.org/users/artists.html
#
# Total flexibility in placing the Axes: we specify `[left, bottom, width, height]` in 0-1 relative figure coordinates.

# %%
f=plt.figure(figsize=(6,4))     #Generamos la figura que será el contenedor
axes1=f.add_axes([0,0,1,1])          # left=0,bottom=0,altura=1,anchura=1, estas dimensiones son respecto al contenedor figure
axes2=f.add_axes([0.10,0.55,0.4,0.4]) 

axes1.plot(xs,ys)
axes2.scatter(xs,ys)
axes2.set_xlim(25,50)
axes2.set_ylim(50,150)
# Out:
# (50, 150)

# %%
plt.gcf()  #GetCurrentFigure
plt.gca()  #GetCurrentAxes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-582b421fc6f2> in <module>
#       1 plt.gcf()  #GetCurrentFigure
#       2 plt.gca()  #GetCurrentAxes
# ----> 3 ds
#
# NameError: name 'ds' is not defined

# %% [markdown]
# ### Subplots
#
# We can add them with either `figure.add_subplot()` or create a figure with its subplots directly by calling `plt.subplots()`

# %%
f=plt.figure(figsize=(6,4))     #Generamos la figura que será el contenedor
axes1=f.add_subplot(2,2,1)      #Estamos indicando que hemos creado 4 subplots (2x2) y estamos dibujando ahora en el 1
axes2=f.add_subplot(1,2,2)      #Estamos indicando que hemos creado 4 subplots (1x2) y estamos dibujando ahora en el 2

axes1.plot(xs,ys)
axes2.scatter(xs,ys)
axes2.set_xlim(25,50)
axes2.set_ylim(50,150)
# Out:
# (50, 150)

# %% [markdown]
# ### `plt.subplots()`

# %%
f,ax=plt.subplots(2,2)   #F será la figura y 'ax' será el array que contiene los axes

ax[0,1].scatter(xs,ys)
ax[1,0].plot(x,np.exp(x)/(1+np.exp(x)),'r')

# %% [markdown]
# ### Sharing axis

# %%
f,ax=plt.subplots(2,1,sharex=True)   #F será la figura y 'ax' será el array que contiene los axes

ax[0].scatter(xs,ys)
ax[1].plot(x,np.exp(x)/(1+np.exp(x)),'b')

# %% [markdown]
# ## `fill_between`
#
# We can fill areas of the plot with solid color
#
# The syntax is
#
# ```python
# plt.fill_between(X, Y1, Y2)
# ```
#
# Where Y1 and Y2 are either `np.array`s or scalar values.

# %%
plt.fill_between([1,2,3],[4,2,7],[2,5,9])

# %%
xs=np.linspace(-3,3,300)

plt.fill_between(xs,xs**2,1/xs)

# %%
xs=np.linspace(-3,3,300)

plt.fill_between(xs,xs**2,xs+3)

# %% [markdown]
# ## `fill_between`(`where=`)
#
# We can fill areas of the plot with solid color differently in different parts of the graph.
#
# The syntax is
#
# ```python
# plt.fill_between(X, Y1, Y2, where=boolean_array)
# ```
#
# Where Y1 and Y2 are either `np.array`s or scalar values, and boolean_array can be constructed from X, from Y, or from whatever you want.

# %%
xs=np.linspace(-3,3,300)

plt.fill_between(xs,xs**2,xs+3,where=xs+3>xs**2)

# %% [markdown]
# #### Exercise:
# Given this code:
# ```python
# n = 256
# X = np.linspace(-np.pi,np.pi,n,endpoint=True)
# Y = np.sin(2*X)
#
# plt.plot (X, Y+1, color='blue', alpha=1.00)
# plt.plot (X, Y-1, color='blue', alpha=1.00)
# plt.show()
# ```
#
# Reproduce this plot:
#
# ![Exercise](figs/plot_ex.png)

# %%
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plt.plot (X, Y+1, color='blue', alpha=1.00)       #alpha indica la opacidad
plt.plot (X, Y-1, color='blue', alpha=1.00)

plt.fill_between(X,Y+1,1,alpha=0.25,color='blue')
plt.fill_between(X,Y-1,-1,alpha=0.25,where=-1>Y-1,color='red')
plt.fill_between(X,Y-1,-1,alpha=0.25,where=-1<Y-1,color='blue')
plt.xticks([])
plt.yticks([])
plt.show()
plt.savefig('sine_exercise.png')

# %% [markdown]
# ## Line properties

# %% [markdown]
# ### Color
#
# See https://matplotlib.org/users/colormaps.html
#
# ![Colormaps](https://matplotlib.org/_images/grayscale_01_00.png)

# %% [markdown]
# Orden de preferencia para dar prioridad a la información:
# - Lo más importante es jugar con la posición
# - Tambien se puede jugar bien con longitudes
# - El tamaño representado es algo más secundario
# - Lo último con lo que tendríamos que representar importancia es con el color (en un mapa es obligatorio por ejemplo). Está bien para separar clases (variables discretas)

# %%
from matplotlib import cm

cmap=cm.get_cmap('inferno')
plt.scatter(xs,np.sin(xs),c=np.cos(xs),cmap=cmap)

# %% [markdown]
# #### Exercise
#
# Given this code, try to reproduce this graphic taking care of marker size, color and transparency.
#
# ```python
# n = 1024
# X = np.random.normal(0,1,n)
# Y = np.random.normal(0,1,n)
#
# plt.scatter(X,Y)
# plt.show()
# ```
#
# ![Color exercise](figs/scatter_ex.png)

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
cmap=cm.get_cmap('spring')

plt.scatter(X,Y,c=np.arctan(X/Y),cmap=cmap)
plt.show()

# %% [markdown]
# ### Markers and linestyles

# %%
xs=np.linspace(0,10)
ys=xs**2

plt.plot(xs,ys,'r--')

# %%
xs=np.linspace(0,10)
ys=xs**2

plt.plot(xs,ys,'r-.')

# %%
xs=np.linspace(0,10)
ys=xs**2

plt.plot(xs,ys,'r^')

# %% [markdown]
# ## Other attributes
#
# http://nbviewer.jupyter.org/github/WeatherGod/AnatomyOfMatplotlib/blob/master/AnatomyOfMatplotlib-Part3-HowToSpeakMPL.ipynb

# %% [markdown]
# ### Histograms

# %%
plt.hist(X,bins=30)  #los bins se pueden expresar o como un número de bins o como unos límites
# Out:
# (array([  1.,   1.,   2.,   6.,   9.,   8.,  25.,  17.,  30.,  41.,  53.,
#          69.,  83., 103.,  81.,  93.,  94.,  77.,  63.,  51.,  35.,  26.,
#          22.,  11.,  11.,   7.,   3.,   0.,   1.,   1.]),
#  array([-3.34844565, -3.12403841, -2.89963116, -2.67522392, -2.45081667,
#         -2.22640943, -2.00200218, -1.77759493, -1.55318769, -1.32878044,
#         -1.1043732 , -0.87996595, -0.65555871, -0.43115146, -0.20674421,
#          0.01766303,  0.24207028,  0.46647752,  0.69088477,  0.91529201,
#          1.13969926,  1.3641065 ,  1.58851375,  1.812921  ,  2.03732824,
#          2.26173549,  2.48614273,  2.71054998,  2.93495722,  3.15936447,
#          3.38377172]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# ## Text and Math: $\LaTeX$
#
# $\LaTeX$ is "a high-quality typesetting system; it includes features designed for the production of technical and scientific documentation. LaTeX is the de facto standard for the communication and publication of scientific documents" ([$LaTeX$ project website](https://www.latex-project.org/)).
#
# It's widely used for writing mathematical equations that need to be rendered accurately.
#
# We can use it in pretty much any place we need to use text.

# %% [markdown]
# # Comprobar

# %% [markdown]
# ## Legends

# %% [markdown]
# # Comprobar

# %% [markdown]
# ## Ticks, tick labels, limits

# %% [markdown]
# ### Ticks, Tick labels, Limits

# %%
xs=np.linspace(0,10)
ys=xs**2

plt.plot(xs,ys,'r--')
ax=plt.gca()
ax.set_xticks([3,7])
ax.set_xticklabels(['hola','que tal'])
ax.set_ylim([20,60])
# Out:
# (20, 60)

# %% [markdown]
# # Seaborn
#
# Seaborn is a statistical data visualization library. It's built on top of matplotlib and tries to "make a well-defined set of hard things easy" ([introduction to Seaborn](http://seaborn.pydata.org/introduction.html)).
#
# One advantage over matplotlib is that it works natively with DataFrame objects.
#
#
# https://www.datacamp.com/community/tutorials/seaborn-python-tutorial

# %% [markdown]
# #### Exercise:
#
# Load the `houses.csv` file into memory as a pandas `DataFrame`. Inspect its head. Clean the column names.

# %%
df=pd.read_csv('houses.csv',index_col='index')
short_column_names = ['local_prices', 'bathrooms', 'site_area', 
                      'living_area', 'garages', 'rooms', 
                      'bedrooms', 'age', 'construction_type', 
                      'architecture', 'fireplaces', 'price']

df.columns = short_column_names
df.head()
# Out:
#        local_prices  bathrooms  site_area  living_area  garages  rooms  \
# index
# 1            4.9176        1.0      3.472        0.998      1.0      7
# 2            5.0208        1.0      3.531        1.500      2.0      7
# 3            4.5429        1.0      2.275        1.175      1.0      6
# 4            4.5573        1.0      4.050        1.232      1.0      6
# 5            5.0597        1.0      4.455        1.121      1.0      6
#
#        bedrooms  age  construction_type  architecture  fireplaces  price
# index
# 1             4   42                  3             1           0   25.9
# 2             4   62                  1             1           0   29.5
# 3             3   40                  2             1           0   27.9
# 4             3   54                  4             1           0   25.9
# 5             3   42                  3             1           0   29.9

# %% [markdown]
# ## Seaborn vs matplotlib

# %% [markdown]
# ## Distribution plots
#
# https://seaborn.pydata.org/tutorial/distributions.html

# %% [markdown]
# ### Scatter plots - .jointplot()

# %%
import seaborn as sns

sns.jointplot(df['site_area'],df['price'])   #En este caso se interpretan como series

# %%
import seaborn as sns

sns.jointplot(data=df,x='site_area',y='price')    #En este caso se interpretan como columnas del df

# %% [markdown]
# Podemos aplicar una 'Kernel density estimation', que consiste en que para cada observación se le aplica una distribución normal (campana de Gauss) y la representación final es la suma total de las distribuciones a lo largo del eje

# %%
import seaborn as sns

sns.jointplot(data=df,x='site_area',y='price', kind='kde')    #kde = kernel density estimation

# %% [markdown]
# ### Histogram - .distplot()

# %%
sns.distplot(np.random.randn(300),bins=40, rug=True) #Lleva implicito la kernel density estimation. 
                                                     #Con rug introduce cada observación

# %% [markdown]
# More on [distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html)

# %% [markdown]
# ### Pairwise relationships .pairplot()

# %%
smaller = df[['local_prices','site_area','living_area','rooms','age']]
smaller.head()
# Out:
#        local_prices  site_area  living_area  rooms  age
# index
# 1            4.9176      3.472        0.998      7   42
# 2            5.0208      3.531        1.500      7   62
# 3            4.5429      2.275        1.175      6   40
# 4            4.5573      4.050        1.232      6   54
# 5            5.0597      4.455        1.121      6   42

# %%
sns.pairplot(smaller)

# %% [markdown]
# Con esto obtenemos las relaciones básicas entre las columnas seleccionadas

# %%
sns.pairplot(smaller,diag_kind='kde',hue='rooms') #Con hue nos centramos en distinguir con colores alguna variable

# %% [markdown]
# ## Linear relationships
#
# https://seaborn.pydata.org/tutorial/regression.html

# %% [markdown]
# ### `lmplot()` Linear Regression

# %%
sns.lmplot(data=smaller,x='site_area',y='local_prices')

# %%
sns.lmplot(data=smaller,x='site_area',y='local_prices')
plt.gcf().set_size_inches(6,4)                          #Se puede aplicar lo que hemos visto en matplotlib

# %% [markdown]
# ## Categorical data
#
# https://www.kaggle.com/c/titanic/download/train.csv
#
# https://seaborn.pydata.org/tutorial/categorical.html

# %%
titanic=pd.read_csv('train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Swarm plot

# %%
sns.stripplot(data=titanic,x='Pclass',y='Fare',hue='Embarked') #Se observa que se apilan los datos abajo

# %%
sns.swarmplot(data=titanic,x='Pclass',y='Fare',hue='Embarked') #Separa los datos para que no se apilen tanto

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data=titanic,x='Embarked',y='Fare',hue='Pclass') #Dibuja los cuartiles principales y outliers

# %% [markdown]
# ### Barplot / countplot

# %%
sns.barplot(data=titanic,x='Embarked',y='Fare',hue='Sex')

# %% [markdown]
# ### Pointplot

# %%
sns.pointplot(data=titanic,x='Embarked',y='Fare',hue='Pclass') #Útil para comparar cambios entre categorias

# %% [markdown]
# ## Other types

# %% [markdown]
# ### Heatmap

# %%
df.head()
# Out:
#        local_prices  bathrooms  site_area  living_area  garages  rooms  \
# index
# 1            4.9176        1.0      3.472        0.998      1.0      7
# 2            5.0208        1.0      3.531        1.500      2.0      7
# 3            4.5429        1.0      2.275        1.175      1.0      6
# 4            4.5573        1.0      4.050        1.232      1.0      6
# 5            5.0597        1.0      4.455        1.121      1.0      6
#
#        bedrooms  age  construction_type  architecture  fireplaces  price
# index
# 1             4   42                  3             1           0   25.9
# 2             4   62                  1             1           0   29.5
# 3             3   40                  2             1           0   27.9
# 4             3   54                  4             1           0   25.9
# 5             3   42                  3             1           0   29.9

# %%
sns.heatmap(df.corr(),cmap='RdBu',center=0) #center=0 para centrar los valores en el 0, no en la mediana

# %% [markdown]
# Se observa que utiliza un cmap secuencial, es decir, colores muy parecidos entre el anterior y el siguiente. Por ello, lo suyo es usar un cmap divergente (mejor que categórico) ya que buscamos los valores más próximos a 1 y -1

# %% [markdown]
# ### Clustermap

# %%
sns.clustermap(df.corr(),cmap='RdBu',center=0)

# %% [markdown]
# # Bokeh
#
# Bokeh "is a Python interactive visualization library that targets
# modern web browsers for presentation".
#
# Two components: A Python backend and a JS frontend.
#
# The way we use it is to declare our graphs in Python.
#
# The Python objects will in turn generate a series of JSON objects that describe a _scenegraph_. The JS component will generate the actual visualization from that scenegraph. The upside of this is that we don't need to work with JS, but our visualizations will be browser-based and interactive
#
# https://bokeh.pydata.org/en/latest/docs/gallery.html
#
# https://bokeh.pydata.org/en/latest/

# %% [markdown]
# # Plotly
#
# https://www.analyticsvidhya.com/blog/2017/01/beginners-guide-to-create-beautiful-interactive-data-visualizations-using-plotly-in-r-and-python/
#
# Plotly is a multi-language tool for creating interactive visualizations. It's built on top  of D3.

# %% [markdown]
# ## Dash
#
# "Shiny for Python"

# %% [markdown]
# # See Also: Vega
#
# http://vega.github.io/

# %% [markdown]
# # Additional references
#
# [Matplotlib documentation](http://matplotlib.org/contents.html)
#
# [The matplotlib FAQ](http://matplotlib.org/faq/usage_faq.html)
#
# [Matplotlib cheat sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
#
# [Nicolas P. Rougier's matplotlib tutorial](http://www.labri.fr/perso/nrougier/teaching/matplotlib/)
#
# [Anatomy of Matplotlib](https://github.com/matplotlib/AnatomyOfMatplotlib)
#
# [$\LaTeX$](https://www.latex-project.org/)

# %% [markdown]
# # Additional references
#
# [Bokeh User Guide](http://bokeh.pydata.org/en/latest/docs/user_guide.html)
#
# [Bokeh Tutorials](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb)
#
# [Dash](https://plot.ly/dash/)
#
# [Dash being spotted before release](https://www.reddit.com/r/Python/comments/6imhxa/plotly_has_just_released_dash_20_a_shinylike_tool/)
#
# [Facets](https://pair-code.github.io/facets/)
#
# [Facets release Google research blog entry](https://research.googleblog.com/2017/07/facets-open-source-visualization-tool.html)
