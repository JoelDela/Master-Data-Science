# %% [markdown]
# A practical introduction to Pandas
# ===================

# %% [markdown]
# We have been asked to *analyze an otp dataset*, without much more information. This kind of scenario is more common than you might imagine!
#
# ## 1) Quickly examine the attached file. What does it contain, in both technical and functional terms? (Use any tool you want)

# %%
! ls -lh On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip
# Out:
# -rw-rw-rw- 1 joeldela joeldela 30M Nov 29 17:04 On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip

# %% [markdown]
# In this example, I am using the shell from within this notebook, with the ! notation:
#
# A ! sign before a line tells the notebook to send that line straight away to the underlying OS.
#
# \* Note that the specific commands available under the ! sign are dependent on the OS.

# %% [markdown]
# ### Check what the file contains

# %%
zip_path='On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip'
! unzip -l $zip_path
# Out:
# Archive:  On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
# 272856955  2019-11-04 17:15   On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2019_9.csv
#     12152  2019-11-04 17:15   readme.html
# ---------                     -------
# 272869107                     2 files

# %% [markdown]
# Oh, it has a readme! Always good to read it.

# %% [markdown]
# ### Unzip the readme to the current directory
#
# Use the shell of your OS or the GUI.
#
# Remember, since zip files contain several compressed files, we need to specify which one we want.

# %%
# Out:
# unzip:  cannot find or open zip_path, zip_path.zip or zip_path.ZIP.

# %% [markdown]
# ### Take a look at the beginning of the readme file
#
# using the shell

# %%
# !unzip -o $zip_path
# Out:
# Archive:  On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip
#   inflating: On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2019_9.csv
#   inflating: readme.html

# %% [markdown]
# The readme file is html. Luckily, we are working in an html environment.
#
# ### Display the contents of `readme.html` within the notebook
# (Hint: check out [IPython.display.IFrame](https://ipython.org/ipython-doc/3/api/generated/IPython.display.html))

# %%
from IPython.display import IFrame

IFrame('readme.html',600,800)    #Cambiando readme.html por otra página web enseñaría dicha página
# Out:
#         <iframe
#             width="600"
#             height="800"
#             src="readme.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# That's some very good documentation!
#
# ### Summary:
#
# The files within the zip are " quoted csv's. They contain information on timeliness of departures in the US, at the departure level.

# %% [markdown]
# ### Load some of the data (one of the files) into memory as a pandas dataframe. What functions do you need to use?
#
# Pro tip: there is no need to decompress the whole file. Check out [zipfile.ZipFile](https://docs.python.org/3/library/zipfile.html)

# %% [markdown]
# First, open a connection to one of the files

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

# %%
pd.read_csv('On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip',)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-b0568960f8fb> in <module>
# ----> 1 pd.read_csv('On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip',)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# ValueError: ('Multiple files found in compressed zip file %s', "['On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2019_9.csv', 'readme.html']")

# %%
from zipfile import ZipFile

zf=ZipFile(zip_path)    #Actuará como un iter
zf
# Out:
# <zipfile.ZipFile filename='On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2019_9.zip' mode='r'>

# %% [markdown]
# zip_file is a connection to the compressed file, the .zip. We can use it to open a connection to one of the files it contains, which will behave like a normal uncompressed file that we had opened with open()

# %%
zf.filelist
# Out:
# [<ZipInfo filename='On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2019_9.csv' compress_type=deflate filemode='-rw-r--r--' file_size=272856955 compress_size=30506023>,
#  <ZipInfo filename='readme.html' compress_type=deflate filemode='-rw-r--r--' file_size=12152 compress_size=2244>]

# %%
csv=zf.open(zf.filelist[0])
csv.readline()
# Out:
# b'"Year","Quarter","Month","DayofMonth","DayOfWeek","FlightDate","Reporting_Airline","DOT_ID_Reporting_Airline","IATA_CODE_Reporting_Airline","Tail_Number","Flight_Number_Reporting_Airline","OriginAirportID","OriginAirportSeqID","OriginCityMarketID","Origin","OriginCityName","OriginState","OriginStateFips","OriginStateName","OriginWac","DestAirportID","DestAirportSeqID","DestCityMarketID","Dest","DestCityName","DestState","DestStateFips","DestStateName","DestWac","CRSDepTime","DepTime","DepDelay","DepDelayMinutes","DepDel15","DepartureDelayGroups","DepTimeBlk","TaxiOut","WheelsOff","WheelsOn","TaxiIn","CRSArrTime","ArrTime","ArrDelay","ArrDelayMinutes","ArrDel15","ArrivalDelayGroups","ArrTimeBlk","Cancelled","CancellationCode","Diverted","CRSElapsedTime","ActualElapsedTime","AirTime","Flights","Distance","DistanceGroup","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay","FirstDepTime","TotalAddGTime","LongestAddGTime","DivAirportLandings","DivReachedDest","DivActualElapsedTime","DivArrDelay","DivDistance","Div1Airport","Div1AirportID","Div1AirportSeqID","Div1WheelsOn","Div1TotalGTime","Div1LongestGTime","Div1WheelsOff","Div1TailNum","Div2Airport","Div2AirportID","Div2AirportSeqID","Div2WheelsOn","Div2TotalGTime","Div2LongestGTime","Div2WheelsOff","Div2TailNum","Div3Airport","Div3AirportID","Div3AirportSeqID","Div3WheelsOn","Div3TotalGTime","Div3LongestGTime","Div3WheelsOff","Div3TailNum","Div4Airport","Div4AirportID","Div4AirportSeqID","Div4WheelsOn","Div4TotalGTime","Div4LongestGTime","Div4WheelsOff","Div4TailNum","Div5Airport","Div5AirportID","Div5AirportSeqID","Div5WheelsOn","Div5TotalGTime","Div5LongestGTime","Div5WheelsOff","Div5TailNum",\n'

# %% [markdown]
# Now we're ready to load the file into memory as a pandas dataframe. Remember to close the connections to the files!

# %%
df=pd.read_csv(csv)
df.head()    #vemos que como antes hemos puesto 'readline()' nos hemos comido la línea que empezaba (el header)
# Out:
#    2019  3  9  2  1  2019-09-02  NK  20416 NK.1  N631NK  ...  Unnamed: 100  \
# 0  2019  3  9  3  2  2019-09-03  NK  20416   NK  N620NK  ...           NaN
# 1  2019  3  9  4  3  2019-09-04  NK  20416   NK  N665NK  ...           NaN
# 2  2019  3  9  5  4  2019-09-05  NK  20416   NK  N672NK  ...           NaN
# 3  2019  3  9  6  5  2019-09-06  NK  20416   NK  N671NK  ...           NaN
# 4  2019  3  9  7  6  2019-09-07  NK  20416   NK  N675NK  ...           NaN
#
#    Unnamed: 101  Unnamed: 102  Unnamed: 103 Unnamed: 104 Unnamed: 105  \
# 0           NaN           NaN           NaN          NaN          NaN
# 1           NaN           NaN           NaN          NaN          NaN
# 2           NaN           NaN           NaN          NaN          NaN
# 3           NaN           NaN           NaN          NaN          NaN
# 4           NaN           NaN           NaN          NaN          NaN
#
#   Unnamed: 106  Unnamed: 107 Unnamed: 108  Unnamed: 109
# 0          NaN           NaN          NaN           NaN
# 1          NaN           NaN          NaN           NaN
# 2          NaN           NaN          NaN           NaN
# 3          NaN           NaN          NaN           NaN
# 4          NaN           NaN          NaN           NaN
#
# [5 rows x 110 columns]

# %%
csv.seek(0)     #Reseteamos el archivo a 0
# Out:
# 0

# %%
df=pd.read_csv(csv)
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2019        3      9           2          1  2019-09-02                NK
# 1  2019        3      9           3          2  2019-09-03                NK
# 2  2019        3      9           4          3  2019-09-04                NK
# 3  2019        3      9           5          4  2019-09-05                NK
# 4  2019        3      9           6          5  2019-09-06                NK
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     20416                          NK      N631NK  ...
# 1                     20416                          NK      N620NK  ...
# 2                     20416                          NK      N665NK  ...
# 3                     20416                          NK      N672NK  ...
# 4                     20416                          NK      N671NK  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# Let's start examining the data: show the beginning of the file. How many records does it contain?

# %%
df.sample(5)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 77386   2019        3      9           5          4  2019-09-05
# 422997  2019        3      9          13          5  2019-09-13
# 133148  2019        3      9          13          5  2019-09-13
# 486584  2019        3      9           5          4  2019-09-05
# 256434  2019        3      9          30          1  2019-09-30
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 77386                 OO                     20304
# 422997                MQ                     20398
# 133148                OO                     20304
# 486584                DL                     19790
# 256434                WN                     19393
#
#        IATA_CODE_Reporting_Airline Tail_Number  ...  Div4TailNum  Div5Airport  \
# 77386                           OO      N8982A  ...          NaN          NaN
# 422997                          MQ      N933JN  ...          NaN          NaN
# 133148                          OO      N913SW  ...          NaN          NaN
# 486584                          DL      N116DU  ...          NaN          NaN
# 256434                          WN      N907WN  ...          NaN          NaN
#
#         Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 77386             NaN               NaN          NaN            NaN
# 422997            NaN               NaN          NaN            NaN
# 133148            NaN               NaN          NaN            NaN
# 486584            NaN               NaN          NaN            NaN
# 256434            NaN               NaN          NaN            NaN
#
#        Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 77386               NaN            NaN         NaN           NaN
# 422997              NaN            NaN         NaN           NaN
# 133148              NaN            NaN         NaN           NaN
# 486584              NaN            NaN         NaN           NaN
# 256434              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
df.shape
# Out:
# (605979, 110)

# %%
pd.options.display.max_columns=120

# %% [markdown]
# ## Trimming the data
#
# The table is quite wide, and it seems that there are many columns without much data. Which, exactly, are those? (let's consider empty a column that doesn't contain at least 1000 records, arbitrarily)

# %%
df.notna().sum().sort_values()
# Out:
# Unnamed: 109             0
# Div3Airport              0
# Div3AirportID            0
# Div3AirportSeqID         0
# Div3WheelsOn             0
#                      ...
# Dest                605979
# DestCityMarketID    605979
# DestAirportSeqID    605979
# DestWac             605979
# Distance            605979
# Length: 110, dtype: int64

# %%
almost_empty_cols=df.columns[df.notna().sum() <= 1000]
amost_empty_cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-2b2a8f683da1> in <module>
#       1 almost_empty_cols=df.columns[df.notna().sum() <= 1000]
# ----> 2 amost_empty_cols
#
# NameError: name 'amost_empty_cols' is not defined

# %% [markdown]
# It seems that the "diverted" fields, after the first, are often empty. No big surprise, since not that many flights must be diverted more than once in a month. Let's drop those columns, since we are not that interested in those, at least for now.

# %%
df2=df.drop(almost_empty_cols,axis=1)
df2
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2019        3      9           2          1  2019-09-02
# 1       2019        3      9           3          2  2019-09-03
# 2       2019        3      9           4          3  2019-09-04
# 3       2019        3      9           5          4  2019-09-05
# 4       2019        3      9           6          5  2019-09-06
# ...      ...      ...    ...         ...        ...         ...
# 605974  2019        3      9          26          4  2019-09-26
# 605975  2019        3      9          27          5  2019-09-27
# 605976  2019        3      9          28          6  2019-09-28
# 605977  2019        3      9          29          7  2019-09-29
# 605978  2019        3      9          30          1  2019-09-30
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                     NK                     20416
# 1                     NK                     20416
# 2                     NK                     20416
# 3                     NK                     20416
# 4                     NK                     20416
# ...                  ...                       ...
# 605974                OH                     20397
# 605975                OH                     20397
# 605976                OH                     20397
# 605977                OH                     20397
# 605978                OH                     20397
#
#        IATA_CODE_Reporting_Airline Tail_Number  \
# 0                               NK      N631NK
# 1                               NK      N620NK
# 2                               NK      N665NK
# 3                               NK      N672NK
# 4                               NK      N671NK
# ...                            ...         ...
# 605974                          OH      N607NN
# 605975                          OH      N590NN
# 605976                          OH      N608NN
# 605977                          OH      N591NN
# 605978                          OH      N576NN
#
#         Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                                  1004            11697             1169706
# 1                                  1004            11697             1169706
# 2                                  1004            11697             1169706
# 3                                  1004            11697             1169706
# 4                                  1004            11697             1169706
# ...                                 ...              ...                 ...
# 605974                             5709            15624             1562404
# 605975                             5709            15624             1562404
# 605976                             5709            15624             1562404
# 605977                             5709            15624             1562404
# 605978                             5709            15624             1562404
#
#         OriginCityMarketID Origin       OriginCityName OriginState  \
# 0                    32467    FLL  Fort Lauderdale, FL          FL
# 1                    32467    FLL  Fort Lauderdale, FL          FL
# 2                    32467    FLL  Fort Lauderdale, FL          FL
# 3                    32467    FLL  Fort Lauderdale, FL          FL
# 4                    32467    FLL  Fort Lauderdale, FL          FL
# ...                    ...    ...                  ...         ...
# 605974               31504    VPS       Valparaiso, FL          FL
# 605975               31504    VPS       Valparaiso, FL          FL
# 605976               31504    VPS       Valparaiso, FL          FL
# 605977               31504    VPS       Valparaiso, FL          FL
# 605978               31504    VPS       Valparaiso, FL          FL
#
#         OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0                    12         Florida         33          14100
# 1                    12         Florida         33          14100
# 2                    12         Florida         33          14100
# 3                    12         Florida         33          14100
# 4                    12         Florida         33          14100
# ...                 ...             ...        ...            ...
# 605974               12         Florida         33          11057
# 605975               12         Florida         33          11057
# 605976               12         Florida         33          11057
# 605977               12         Florida         33          11057
# 605978               12         Florida         33          11057
#
#         DestAirportSeqID  DestCityMarketID Dest      DestCityName DestState  \
# 0                1410005             34100  PHL  Philadelphia, PA        PA
# 1                1410005             34100  PHL  Philadelphia, PA        PA
# 2                1410005             34100  PHL  Philadelphia, PA        PA
# 3                1410005             34100  PHL  Philadelphia, PA        PA
# 4                1410005             34100  PHL  Philadelphia, PA        PA
# ...                  ...               ...  ...               ...       ...
# 605974           1105703             31057  CLT     Charlotte, NC        NC
# 605975           1105703             31057  CLT     Charlotte, NC        NC
# 605976           1105703             31057  CLT     Charlotte, NC        NC
# 605977           1105703             31057  CLT     Charlotte, NC        NC
# 605978           1105703             31057  CLT     Charlotte, NC        NC
#
#         DestStateFips   DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 0                  42    Pennsylvania       23        2055      NaN       NaN
# 1                  42    Pennsylvania       23        2055   2048.0      -7.0
# 2                  42    Pennsylvania       23        2045   2054.0       9.0
# 3                  42    Pennsylvania       23        2045   2044.0      -1.0
# 4                  42    Pennsylvania       23        2045   2040.0      -5.0
# ...               ...             ...      ...         ...      ...       ...
# 605974             37  North Carolina       36        1859   1847.0     -12.0
# 605975             37  North Carolina       36        1859   1857.0      -2.0
# 605976             37  North Carolina       36        1859   1849.0     -10.0
# 605977             37  North Carolina       36        1859   1852.0      -7.0
# 605978             37  North Carolina       36        1859   2003.0      64.0
#
#         DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 0                   NaN       NaN                   NaN  2000-2059      NaN
# 1                   0.0       0.0                  -1.0  2000-2059     14.0
# 2                   9.0       0.0                   0.0  2000-2059     12.0
# 3                   0.0       0.0                  -1.0  2000-2059     15.0
# 4                   0.0       0.0                  -1.0  2000-2059     10.0
# ...                 ...       ...                   ...        ...      ...
# 605974              0.0       0.0                  -1.0  1800-1859     14.0
# 605975              0.0       0.0                  -1.0  1800-1859     13.0
# 605976              0.0       0.0                  -1.0  1800-1859     22.0
# 605977              0.0       0.0                  -1.0  1800-1859     10.0
# 605978             64.0       1.0                   4.0  1800-1859      9.0
#
#         WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 0             NaN       NaN     NaN        2343      NaN       NaN
# 1          2102.0    2312.0    11.0        2343   2323.0     -20.0
# 2          2106.0    2338.0    13.0        2333   2351.0      18.0
# 3          2059.0    2317.0    13.0        2340   2330.0     -10.0
# 4          2050.0    2259.0    11.0        2340   2310.0     -30.0
# ...           ...       ...     ...         ...      ...       ...
# 605974     1901.0    2110.0    12.0        2144   2122.0     -22.0
# 605975     1910.0    2125.0     6.0        2144   2131.0     -13.0
# 605976     1911.0    2120.0    13.0        2144   2133.0     -11.0
# 605977     1902.0    2110.0    18.0        2144   2128.0     -16.0
# 605978     2012.0    2224.0    25.0        2144   2249.0      65.0
#
#         ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 0                   NaN       NaN                 NaN  2300-2359        1.0
# 1                   0.0       0.0                -2.0  2300-2359        0.0
# 2                  18.0       1.0                 1.0  2300-2359        0.0
# 3                   0.0       0.0                -1.0  2300-2359        0.0
# 4                   0.0       0.0                -2.0  2300-2359        0.0
# ...                 ...       ...                 ...        ...        ...
# 605974              0.0       0.0                -2.0  2100-2159        0.0
# 605975              0.0       0.0                -1.0  2100-2159        0.0
# 605976              0.0       0.0                -1.0  2100-2159        0.0
# 605977              0.0       0.0                -2.0  2100-2159        0.0
# 605978             65.0       1.0                 4.0  2100-2159        0.0
#
#        CancellationCode  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0                     B       0.0           168.0                NaN      NaN
# 1                   NaN       0.0           168.0              155.0    130.0
# 2                   NaN       0.0           168.0              177.0    152.0
# 3                   NaN       0.0           175.0              166.0    138.0
# 4                   NaN       0.0           175.0              150.0    129.0
# ...                 ...       ...             ...                ...      ...
# 605974              NaN       0.0           105.0               95.0     69.0
# 605975              NaN       0.0           105.0               94.0     75.0
# 605976              NaN       0.0           105.0              104.0     69.0
# 605977              NaN       0.0           105.0               96.0     68.0
# 605978              NaN       0.0           105.0              106.0     72.0
#
#         Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  \
# 0           1.0     992.0              4           NaN           NaN
# 1           1.0     992.0              4           NaN           NaN
# 2           1.0     992.0              4           9.0           0.0
# 3           1.0     992.0              4           NaN           NaN
# 4           1.0     992.0              4           NaN           NaN
# ...         ...       ...            ...           ...           ...
# 605974      1.0     460.0              2           NaN           NaN
# 605975      1.0     460.0              2           NaN           NaN
# 605976      1.0     460.0              2           NaN           NaN
# 605977      1.0     460.0              2           NaN           NaN
# 605978      1.0     460.0              2           8.0           0.0
#
#         NASDelay  SecurityDelay  LateAircraftDelay  FirstDepTime  \
# 0            NaN            NaN                NaN           NaN
# 1            NaN            NaN                NaN           NaN
# 2            9.0            0.0                0.0           NaN
# 3            NaN            NaN                NaN           NaN
# 4            NaN            NaN                NaN           NaN
# ...          ...            ...                ...           ...
# 605974       NaN            NaN                NaN           NaN
# 605975       NaN            NaN                NaN           NaN
# 605976       NaN            NaN                NaN           NaN
# 605977       NaN            NaN                NaN           NaN
# 605978       1.0            0.0               56.0           NaN
#
#         TotalAddGTime  LongestAddGTime  DivAirportLandings  DivReachedDest  \
# 0                 NaN              NaN                   0             NaN
# 1                 NaN              NaN                   0             NaN
# 2                 NaN              NaN                   0             NaN
# 3                 NaN              NaN                   0             NaN
# 4                 NaN              NaN                   0             NaN
# ...               ...              ...                 ...             ...
# 605974            NaN              NaN                   0             NaN
# 605975            NaN              NaN                   0             NaN
# 605976            NaN              NaN                   0             NaN
# 605977            NaN              NaN                   0             NaN
# 605978            NaN              NaN                   0             NaN
#
#         DivActualElapsedTime  DivArrDelay  DivDistance Div1Airport  \
# 0                        NaN          NaN          NaN         NaN
# 1                        NaN          NaN          NaN         NaN
# 2                        NaN          NaN          NaN         NaN
# 3                        NaN          NaN          NaN         NaN
# 4                        NaN          NaN          NaN         NaN
# ...                      ...          ...          ...         ...
# 605974                   NaN          NaN          NaN         NaN
# 605975                   NaN          NaN          NaN         NaN
# 605976                   NaN          NaN          NaN         NaN
# 605977                   NaN          NaN          NaN         NaN
# 605978                   NaN          NaN          NaN         NaN
#
#         Div1AirportID  Div1AirportSeqID  Div1WheelsOn  Div1TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 605974            NaN               NaN           NaN             NaN
# 605975            NaN               NaN           NaN             NaN
# 605976            NaN               NaN           NaN             NaN
# 605977            NaN               NaN           NaN             NaN
# 605978            NaN               NaN           NaN             NaN
#
#         Div1LongestGTime  Div1WheelsOff Div1TailNum
# 0                    NaN            NaN         NaN
# 1                    NaN            NaN         NaN
# 2                    NaN            NaN         NaN
# 3                    NaN            NaN         NaN
# 4                    NaN            NaN         NaN
# ...                  ...            ...         ...
# 605974               NaN            NaN         NaN
# 605975               NaN            NaN         NaN
# 605976               NaN            NaN         NaN
# 605977               NaN            NaN         NaN
# 605978               NaN            NaN         NaN
#
# [605979 rows x 77 columns]

# %%
df2=df.dropna(axis=1,thresh=1000)    #hace lo mismo que en el caso anterior
df2
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2019        3      9           2          1  2019-09-02
# 1       2019        3      9           3          2  2019-09-03
# 2       2019        3      9           4          3  2019-09-04
# 3       2019        3      9           5          4  2019-09-05
# 4       2019        3      9           6          5  2019-09-06
# ...      ...      ...    ...         ...        ...         ...
# 605974  2019        3      9          26          4  2019-09-26
# 605975  2019        3      9          27          5  2019-09-27
# 605976  2019        3      9          28          6  2019-09-28
# 605977  2019        3      9          29          7  2019-09-29
# 605978  2019        3      9          30          1  2019-09-30
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                     NK                     20416
# 1                     NK                     20416
# 2                     NK                     20416
# 3                     NK                     20416
# 4                     NK                     20416
# ...                  ...                       ...
# 605974                OH                     20397
# 605975                OH                     20397
# 605976                OH                     20397
# 605977                OH                     20397
# 605978                OH                     20397
#
#        IATA_CODE_Reporting_Airline Tail_Number  \
# 0                               NK      N631NK
# 1                               NK      N620NK
# 2                               NK      N665NK
# 3                               NK      N672NK
# 4                               NK      N671NK
# ...                            ...         ...
# 605974                          OH      N607NN
# 605975                          OH      N590NN
# 605976                          OH      N608NN
# 605977                          OH      N591NN
# 605978                          OH      N576NN
#
#         Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                                  1004            11697             1169706
# 1                                  1004            11697             1169706
# 2                                  1004            11697             1169706
# 3                                  1004            11697             1169706
# 4                                  1004            11697             1169706
# ...                                 ...              ...                 ...
# 605974                             5709            15624             1562404
# 605975                             5709            15624             1562404
# 605976                             5709            15624             1562404
# 605977                             5709            15624             1562404
# 605978                             5709            15624             1562404
#
#         OriginCityMarketID Origin       OriginCityName OriginState  \
# 0                    32467    FLL  Fort Lauderdale, FL          FL
# 1                    32467    FLL  Fort Lauderdale, FL          FL
# 2                    32467    FLL  Fort Lauderdale, FL          FL
# 3                    32467    FLL  Fort Lauderdale, FL          FL
# 4                    32467    FLL  Fort Lauderdale, FL          FL
# ...                    ...    ...                  ...         ...
# 605974               31504    VPS       Valparaiso, FL          FL
# 605975               31504    VPS       Valparaiso, FL          FL
# 605976               31504    VPS       Valparaiso, FL          FL
# 605977               31504    VPS       Valparaiso, FL          FL
# 605978               31504    VPS       Valparaiso, FL          FL
#
#         OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0                    12         Florida         33          14100
# 1                    12         Florida         33          14100
# 2                    12         Florida         33          14100
# 3                    12         Florida         33          14100
# 4                    12         Florida         33          14100
# ...                 ...             ...        ...            ...
# 605974               12         Florida         33          11057
# 605975               12         Florida         33          11057
# 605976               12         Florida         33          11057
# 605977               12         Florida         33          11057
# 605978               12         Florida         33          11057
#
#         DestAirportSeqID  DestCityMarketID Dest      DestCityName DestState  \
# 0                1410005             34100  PHL  Philadelphia, PA        PA
# 1                1410005             34100  PHL  Philadelphia, PA        PA
# 2                1410005             34100  PHL  Philadelphia, PA        PA
# 3                1410005             34100  PHL  Philadelphia, PA        PA
# 4                1410005             34100  PHL  Philadelphia, PA        PA
# ...                  ...               ...  ...               ...       ...
# 605974           1105703             31057  CLT     Charlotte, NC        NC
# 605975           1105703             31057  CLT     Charlotte, NC        NC
# 605976           1105703             31057  CLT     Charlotte, NC        NC
# 605977           1105703             31057  CLT     Charlotte, NC        NC
# 605978           1105703             31057  CLT     Charlotte, NC        NC
#
#         DestStateFips   DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 0                  42    Pennsylvania       23        2055      NaN       NaN
# 1                  42    Pennsylvania       23        2055   2048.0      -7.0
# 2                  42    Pennsylvania       23        2045   2054.0       9.0
# 3                  42    Pennsylvania       23        2045   2044.0      -1.0
# 4                  42    Pennsylvania       23        2045   2040.0      -5.0
# ...               ...             ...      ...         ...      ...       ...
# 605974             37  North Carolina       36        1859   1847.0     -12.0
# 605975             37  North Carolina       36        1859   1857.0      -2.0
# 605976             37  North Carolina       36        1859   1849.0     -10.0
# 605977             37  North Carolina       36        1859   1852.0      -7.0
# 605978             37  North Carolina       36        1859   2003.0      64.0
#
#         DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 0                   NaN       NaN                   NaN  2000-2059      NaN
# 1                   0.0       0.0                  -1.0  2000-2059     14.0
# 2                   9.0       0.0                   0.0  2000-2059     12.0
# 3                   0.0       0.0                  -1.0  2000-2059     15.0
# 4                   0.0       0.0                  -1.0  2000-2059     10.0
# ...                 ...       ...                   ...        ...      ...
# 605974              0.0       0.0                  -1.0  1800-1859     14.0
# 605975              0.0       0.0                  -1.0  1800-1859     13.0
# 605976              0.0       0.0                  -1.0  1800-1859     22.0
# 605977              0.0       0.0                  -1.0  1800-1859     10.0
# 605978             64.0       1.0                   4.0  1800-1859      9.0
#
#         WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 0             NaN       NaN     NaN        2343      NaN       NaN
# 1          2102.0    2312.0    11.0        2343   2323.0     -20.0
# 2          2106.0    2338.0    13.0        2333   2351.0      18.0
# 3          2059.0    2317.0    13.0        2340   2330.0     -10.0
# 4          2050.0    2259.0    11.0        2340   2310.0     -30.0
# ...           ...       ...     ...         ...      ...       ...
# 605974     1901.0    2110.0    12.0        2144   2122.0     -22.0
# 605975     1910.0    2125.0     6.0        2144   2131.0     -13.0
# 605976     1911.0    2120.0    13.0        2144   2133.0     -11.0
# 605977     1902.0    2110.0    18.0        2144   2128.0     -16.0
# 605978     2012.0    2224.0    25.0        2144   2249.0      65.0
#
#         ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 0                   NaN       NaN                 NaN  2300-2359        1.0
# 1                   0.0       0.0                -2.0  2300-2359        0.0
# 2                  18.0       1.0                 1.0  2300-2359        0.0
# 3                   0.0       0.0                -1.0  2300-2359        0.0
# 4                   0.0       0.0                -2.0  2300-2359        0.0
# ...                 ...       ...                 ...        ...        ...
# 605974              0.0       0.0                -2.0  2100-2159        0.0
# 605975              0.0       0.0                -1.0  2100-2159        0.0
# 605976              0.0       0.0                -1.0  2100-2159        0.0
# 605977              0.0       0.0                -2.0  2100-2159        0.0
# 605978             65.0       1.0                 4.0  2100-2159        0.0
#
#        CancellationCode  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0                     B       0.0           168.0                NaN      NaN
# 1                   NaN       0.0           168.0              155.0    130.0
# 2                   NaN       0.0           168.0              177.0    152.0
# 3                   NaN       0.0           175.0              166.0    138.0
# 4                   NaN       0.0           175.0              150.0    129.0
# ...                 ...       ...             ...                ...      ...
# 605974              NaN       0.0           105.0               95.0     69.0
# 605975              NaN       0.0           105.0               94.0     75.0
# 605976              NaN       0.0           105.0              104.0     69.0
# 605977              NaN       0.0           105.0               96.0     68.0
# 605978              NaN       0.0           105.0              106.0     72.0
#
#         Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  \
# 0           1.0     992.0              4           NaN           NaN
# 1           1.0     992.0              4           NaN           NaN
# 2           1.0     992.0              4           9.0           0.0
# 3           1.0     992.0              4           NaN           NaN
# 4           1.0     992.0              4           NaN           NaN
# ...         ...       ...            ...           ...           ...
# 605974      1.0     460.0              2           NaN           NaN
# 605975      1.0     460.0              2           NaN           NaN
# 605976      1.0     460.0              2           NaN           NaN
# 605977      1.0     460.0              2           NaN           NaN
# 605978      1.0     460.0              2           8.0           0.0
#
#         NASDelay  SecurityDelay  LateAircraftDelay  FirstDepTime  \
# 0            NaN            NaN                NaN           NaN
# 1            NaN            NaN                NaN           NaN
# 2            9.0            0.0                0.0           NaN
# 3            NaN            NaN                NaN           NaN
# 4            NaN            NaN                NaN           NaN
# ...          ...            ...                ...           ...
# 605974       NaN            NaN                NaN           NaN
# 605975       NaN            NaN                NaN           NaN
# 605976       NaN            NaN                NaN           NaN
# 605977       NaN            NaN                NaN           NaN
# 605978       1.0            0.0               56.0           NaN
#
#         TotalAddGTime  LongestAddGTime  DivAirportLandings  DivReachedDest  \
# 0                 NaN              NaN                   0             NaN
# 1                 NaN              NaN                   0             NaN
# 2                 NaN              NaN                   0             NaN
# 3                 NaN              NaN                   0             NaN
# 4                 NaN              NaN                   0             NaN
# ...               ...              ...                 ...             ...
# 605974            NaN              NaN                   0             NaN
# 605975            NaN              NaN                   0             NaN
# 605976            NaN              NaN                   0             NaN
# 605977            NaN              NaN                   0             NaN
# 605978            NaN              NaN                   0             NaN
#
#         DivActualElapsedTime  DivArrDelay  DivDistance Div1Airport  \
# 0                        NaN          NaN          NaN         NaN
# 1                        NaN          NaN          NaN         NaN
# 2                        NaN          NaN          NaN         NaN
# 3                        NaN          NaN          NaN         NaN
# 4                        NaN          NaN          NaN         NaN
# ...                      ...          ...          ...         ...
# 605974                   NaN          NaN          NaN         NaN
# 605975                   NaN          NaN          NaN         NaN
# 605976                   NaN          NaN          NaN         NaN
# 605977                   NaN          NaN          NaN         NaN
# 605978                   NaN          NaN          NaN         NaN
#
#         Div1AirportID  Div1AirportSeqID  Div1WheelsOn  Div1TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 605974            NaN               NaN           NaN             NaN
# 605975            NaN               NaN           NaN             NaN
# 605976            NaN               NaN           NaN             NaN
# 605977            NaN               NaN           NaN             NaN
# 605978            NaN               NaN           NaN             NaN
#
#         Div1LongestGTime  Div1WheelsOff Div1TailNum
# 0                    NaN            NaN         NaN
# 1                    NaN            NaN         NaN
# 2                    NaN            NaN         NaN
# 3                    NaN            NaN         NaN
# 4                    NaN            NaN         NaN
# ...                  ...            ...         ...
# 605974               NaN            NaN         NaN
# 605975               NaN            NaN         NaN
# 605976               NaN            NaN         NaN
# 605977               NaN            NaN         NaN
# 605978               NaN            NaN         NaN
#
# [605979 rows x 77 columns]

# %% [markdown]
# Now that we have eliminated some inconvenient data columns, let's have a look at the rest: let's loook at how the location data is encoded.

# %% [markdown]
# #### Exercise:
#
# First, generate a list of the columns that have 'Origin' in their name
#
# Second, show a sample of the values that those columns take.
#
# Hint: we are going to use the str attribute of Series and Indexes

# %%
origin_list=[]

for col in df.columns:
    if 'Origin' in col:
        origin_list.append(col)
        
origin_list

df[origin_list].sample()
# Out:
#       OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 8455            12892             1289208               32575    LAX
#
#        OriginCityName OriginState  OriginStateFips OriginStateName  OriginWac
# 8455  Los Angeles, CA          CA                6      California         91

# %%
origin_list=df.columns.str.contains('Origin')

sample = df.columns[origin_list]

df[sample].sample()
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 130008            14689             1468902               34689    SBA
#
#            OriginCityName OriginState  OriginStateFips OriginStateName  \
# 130008  Santa Barbara, CA          CA                6      California
#
#         OriginWac
# 130008         91

# %% [markdown]
# So much redundant information!

# %% [markdown]
# ## Fast forward
#
# Just taking out the redundant columns would take a while, so let's jump ahead with this list of interesting columns:
#
# ```python
# interesting_columns= ['FlightDate', 'DayOfWeek', 'Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline',
#                       'Origin', 'OriginCityName', 'OriginStateName', 'OriginCityMarketID',
#                       'Dest', 'DestCityName', 'DestStateName', 'DestCityMarketID',
#                       'DepTime', 'DepDelay', 'AirTime', 'Distance']
# ```

# %%
interesting_columns= ['FlightDate', 'DayOfWeek', 'Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline', 
                      'Origin', 'OriginCityName', 'OriginStateName', 'OriginCityMarketID',
                      'Dest', 'DestCityName', 'DestStateName', 'DestCityMarketID',
                      'DepTime', 'DepDelay', 'AirTime', 'Distance']

df3=df2[interesting_columns]
df3
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 0       2019-09-02          1                NK      N631NK
# 1       2019-09-03          2                NK      N620NK
# 2       2019-09-04          3                NK      N665NK
# 3       2019-09-05          4                NK      N672NK
# 4       2019-09-06          5                NK      N671NK
# ...            ...        ...               ...         ...
# 605974  2019-09-26          4                OH      N607NN
# 605975  2019-09-27          5                OH      N590NN
# 605976  2019-09-28          6                OH      N608NN
# 605977  2019-09-29          7                OH      N591NN
# 605978  2019-09-30          1                OH      N576NN
#
#         Flight_Number_Reporting_Airline Origin       OriginCityName  \
# 0                                  1004    FLL  Fort Lauderdale, FL
# 1                                  1004    FLL  Fort Lauderdale, FL
# 2                                  1004    FLL  Fort Lauderdale, FL
# 3                                  1004    FLL  Fort Lauderdale, FL
# 4                                  1004    FLL  Fort Lauderdale, FL
# ...                                 ...    ...                  ...
# 605974                             5709    VPS       Valparaiso, FL
# 605975                             5709    VPS       Valparaiso, FL
# 605976                             5709    VPS       Valparaiso, FL
# 605977                             5709    VPS       Valparaiso, FL
# 605978                             5709    VPS       Valparaiso, FL
#
#        OriginStateName  OriginCityMarketID Dest      DestCityName  \
# 0              Florida               32467  PHL  Philadelphia, PA
# 1              Florida               32467  PHL  Philadelphia, PA
# 2              Florida               32467  PHL  Philadelphia, PA
# 3              Florida               32467  PHL  Philadelphia, PA
# 4              Florida               32467  PHL  Philadelphia, PA
# ...                ...                 ...  ...               ...
# 605974         Florida               31504  CLT     Charlotte, NC
# 605975         Florida               31504  CLT     Charlotte, NC
# 605976         Florida               31504  CLT     Charlotte, NC
# 605977         Florida               31504  CLT     Charlotte, NC
# 605978         Florida               31504  CLT     Charlotte, NC
#
#          DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  Distance
# 0         Pennsylvania             34100      NaN       NaN      NaN     992.0
# 1         Pennsylvania             34100   2048.0      -7.0    130.0     992.0
# 2         Pennsylvania             34100   2054.0       9.0    152.0     992.0
# 3         Pennsylvania             34100   2044.0      -1.0    138.0     992.0
# 4         Pennsylvania             34100   2040.0      -5.0    129.0     992.0
# ...                ...               ...      ...       ...      ...       ...
# 605974  North Carolina             31057   1847.0     -12.0     69.0     460.0
# 605975  North Carolina             31057   1857.0      -2.0     75.0     460.0
# 605976  North Carolina             31057   1849.0     -10.0     69.0     460.0
# 605977  North Carolina             31057   1852.0      -7.0     68.0     460.0
# 605978  North Carolina             31057   2003.0      64.0     72.0     460.0
#
# [605979 rows x 17 columns]

# %% [markdown]
# ## Formatting columns and parsing dates and times
#
# Hurray! we have almost cleaned our dataset. Soon we will begin to do some actual work with it.

# %%
df3.dtypes
# Out:
# FlightDate                          object
# DayOfWeek                            int64
# Reporting_Airline                   object
# Tail_Number                         object
# Flight_Number_Reporting_Airline      int64
# Origin                              object
# OriginCityName                      object
# OriginStateName                     object
# OriginCityMarketID                   int64
# Dest                                object
# DestCityName                        object
# DestStateName                       object
# DestCityMarketID                     int64
# DepTime                            float64
# DepDelay                           float64
# AirTime                            float64
# Distance                           float64
# dtype: object

# %% [markdown]
# Pandas interpreted the Deptime column as ints and the FlightDate column as strings. We might want to combine them and parse them into a DateTime column, so that we can use them properly as datetimes. For that, we would need to use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html).

# %% [markdown]
# Also, a pet peeve of mine: Flight numbers are names, not numbers!

# %%
df3['Flight_Number_Reporting_Airline'].astype(str)
# Out:
# 0         1004
# 1         1004
# 2         1004
# 3         1004
# 4         1004
#           ...
# 605974    5709
# 605975    5709
# 605976    5709
# 605977    5709
# 605978    5709
# Name: Flight_Number_Reporting_Airline, Length: 605979, dtype: object

# %% [markdown]
# ## Examining the data

# %% [markdown]
# Finally clean! Let's start to do some preliminary work on the data.

# %% [markdown]
# #### Exercise:
#
# Find the biggest delays: 5 maximum delays.

# %%
df3['DepDelay'].sort_values(ascending=False).head(5)
# Out:
# 413463    1753.0
# 390701    1584.0
# 587829    1525.0
# 141845    1513.0
# 107081    1506.0
# Name: DepDelay, dtype: float64

# %%
df3.sort_values(by='DepDelay',ascending=False)
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 413463  2019-09-09          1                MQ      N697AB
# 390701  2019-09-02          1                EV      N14573
# 587829  2019-09-16          1                UA      N19130
# 141845  2019-09-27          5                OO      N150SY
# 107081  2019-09-16          1                OO      N836SK
# ...            ...        ...               ...         ...
# 605494  2019-09-27          5                OH      N593NN
# 605510  2019-09-15          7                OH      N257PS
# 605536  2019-09-15          7                OH      N257PS
# 605554  2019-09-05          4                OH      N702PS
# 605555  2019-09-06          5                OH         NaN
#
#         Flight_Number_Reporting_Airline Origin    OriginCityName  \
# 413463                             3573    RST     Rochester, MN
# 390701                             4162    CVG    Cincinnati, OH
# 587829                             2032    MCO       Orlando, FL
# 141845                             5441    MSP   Minneapolis, MN
# 107081                             3633    ICT       Wichita, KS
# ...                                 ...    ...               ...
# 605494                             5690    MSN       Madison, WI
# 605510                             5691    DAY        Dayton, OH
# 605536                             5691    LGA      New York, NY
# 605554                             5692    PHL  Philadelphia, PA
# 605555                             5692    PHL  Philadelphia, PA
#
#        OriginStateName  OriginCityMarketID Dest     DestCityName  \
# 413463       Minnesota               32547  ORD      Chicago, IL
# 390701        Kentucky               33105  ORD      Chicago, IL
# 587829         Florida               31454  EWR       Newark, NJ
# 141845       Minnesota               31650  ORD      Chicago, IL
# 107081          Kansas               30928  MSP  Minneapolis, MN
# ...                ...                 ...  ...              ...
# 605494       Wisconsin               33485  CLT    Charlotte, NC
# 605510            Ohio               31267  LGA     New York, NY
# 605536        New York               31703  DAY       Dayton, OH
# 605554    Pennsylvania               34100  ORF      Norfolk, VA
# 605555    Pennsylvania               34100  ORF      Norfolk, VA
#
#          DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  Distance
# 413463        Illinois             30977   1942.0    1753.0     50.0     268.0
# 390701        Illinois             30977   2214.0    1584.0     49.0     264.0
# 587829      New Jersey             31703    830.0    1525.0    123.0     937.0
# 141845        Illinois             30977   1215.0    1513.0     54.0     334.0
# 107081       Minnesota             31650    731.0    1506.0     77.0     545.0
# ...                ...               ...      ...       ...      ...       ...
# 605494  North Carolina             31057      NaN       NaN      NaN     708.0
# 605510        New York             31703      NaN       NaN      NaN     549.0
# 605536            Ohio             31267      NaN       NaN      NaN     549.0
# 605554        Virginia             33667      NaN       NaN      NaN     212.0
# 605555        Virginia             33667      NaN       NaN      NaN     212.0
#
# [605979 rows x 17 columns]

# %% [markdown]
# #### Exercise
#
# What was the average delay for this month? Standard deviation and typical value?

# %%
df3.describe()
# Out:
#            DayOfWeek  Flight_Number_Reporting_Airline  OriginCityMarketID  \
# count  605979.000000                    605979.000000       605979.000000
# mean        3.924228                      2553.190155        31727.722362
# std         2.074963                      1787.216561         1302.291509
# min         1.000000                         1.000000        30070.000000
# 25%         2.000000                      1027.000000        30693.000000
# 50%         4.000000                      2149.000000        31453.000000
# 75%         6.000000                      3935.000000        32467.000000
# max         7.000000                      6998.000000        35991.000000
#
#        DestCityMarketID        DepTime       DepDelay        AirTime  \
# count     605979.000000  596198.000000  596198.000000  594716.000000
# mean       31727.890871    1328.786985       6.421335     108.495852
# std         1302.457897     497.344200      41.306174      68.889984
# min        30070.000000       1.000000     -62.000000       6.000000
# 25%        30693.000000     916.000000      -6.000000      59.000000
# 50%        31453.000000    1322.000000      -3.000000      90.000000
# 75%        32467.000000    1738.000000       2.000000     136.000000
# max        35991.000000    2400.000000    1753.000000     665.000000
#
#             Distance
# count  605979.000000
# mean      787.482718
# std       588.102800
# min        31.000000
# 25%       361.000000
# 50%       622.000000
# 75%      1013.000000
# max      5095.000000

# %% [markdown]
# Also: a quick look at the correlation between the numerical variables is extremely easy with pandas:

# %%
df3.corr()
# Out:
#                                  DayOfWeek  Flight_Number_Reporting_Airline  \
# DayOfWeek                         1.000000                         0.055036
# Flight_Number_Reporting_Airline   0.055036                         1.000000
# OriginCityMarketID                0.003038                         0.013448
# DestCityMarketID                  0.003036                         0.008839
# DepTime                           0.003018                        -0.002602
# DepDelay                         -0.005445                         0.007398
# AirTime                           0.013200                        -0.325861
# Distance                          0.013701                        -0.339310
#
#                                  OriginCityMarketID  DestCityMarketID  \
# DayOfWeek                                  0.003038          0.003036
# Flight_Number_Reporting_Airline            0.013448          0.008839
# OriginCityMarketID                         1.000000         -0.052015
# DestCityMarketID                          -0.052015          1.000000
# DepTime                                   -0.052797          0.062610
# DepDelay                                  -0.010868          0.001942
# AirTime                                    0.004599          0.007615
# Distance                                   0.006441          0.005803
#
#                                   DepTime  DepDelay   AirTime  Distance
# DayOfWeek                        0.003018 -0.005445  0.013200  0.013701
# Flight_Number_Reporting_Airline -0.002602  0.007398 -0.325861 -0.339310
# OriginCityMarketID              -0.052797 -0.010868  0.004599  0.006441
# DestCityMarketID                 0.062610  0.001942  0.007615  0.005803
# DepTime                          1.000000  0.117495 -0.023755 -0.018450
# DepDelay                         0.117495  1.000000  0.026840  0.024777
# AirTime                         -0.023755  0.026840  1.000000  0.989630
# Distance                        -0.018450  0.024777  0.989630  1.000000

# %%
import seaborn as sns

sns.heatmap(df3.corr(),center=0)

# %% [markdown]
# #### Exercise
#
# What is the plane that has the highest average delay? We'll first group by tail number (the *license plate* of a plane) and then calculate the relevant statistic for each group (group of *departures*)

# %%
df3.groupby('Tail_Number').mean().sort_values(by='DepDelay',ascending=False).head(1)
# Out:
#              DayOfWeek  Flight_Number_Reporting_Airline  OriginCityMarketID  \
# Tail_Number
# N216UA        1.666667                           1408.0        31377.666667
#
#              DestCityMarketID  DepTime    DepDelay     AirTime     Distance
# Tail_Number
# N216UA           31377.666667   1210.0  401.666667  127.333333  1014.666667

# %%
df3['DepDelay'].groupby(df3['Tail_Number']).mean()
# Out:
# Tail_Number
# 215NV     2.253521
# 216NV     1.014286
# 217NV     5.215909
# 218NV     0.861538
# 219NV    -4.737374
#             ...
# N998DL    5.424242
# N998JE   -1.881579
# N998NN    4.453333
# N999DN    0.240000
# N999JQ   -2.363636
# Name: DepDelay, Length: 5392, dtype: float64

# %% [markdown]
# Oh, but those numbers smell like these planes had only a few, very delayed, departures! how can we count the number of departures *and* calculate the average delay at the same time?

# %%
df3.groupby('Tail_Number')['DepDelay'].agg(['mean','count']).sort_values(by='mean',ascending=False).head(5)
# Out:
#                    mean  count
# Tail_Number
# N216UA       401.666667      3
# N13954       276.000000      2
# N799UA       239.333333      3
# N648UA       236.666667      6
# N225UA       207.000000      2

# %% [markdown]
# Awesome! now, let's look at the average delay of the planes with some departures (let's say, at least 15)

# %%
delays_per_plane=df3.groupby('Tail_Number')['DepDelay'].agg(['mean','count'])
consistently_delay=delays_per_plane[delays_per_plane['count']>=15].sort_values(by='mean',ascending=False).head(5)
consistently_delay
# Out:
#                    mean  count
# Tail_Number
# N339JB       110.500000     18
# N397AN        74.760000     25
# N19130        62.183673     49
# N777UA        54.645161     62
# N771UA        52.438596     57

# %%
df3[[num in consistently_delay.index for num in df3['Tail_Number']]]
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 281057  2019-09-21          6                AA      N397AN
# 284270  2019-09-03          2                AA      N397AN
# 284289  2019-09-22          7                AA      N397AN
# 284300  2019-09-03          2                AA      N397AN
# 292835  2019-09-13          5                AA      N397AN
# ...            ...        ...               ...         ...
# 594074  2019-09-01          7                UA      N777UA
# 594325  2019-09-01          7                UA      N771UA
# 594435  2019-09-01          7                UA      N777UA
# 594634  2019-09-01          7                UA      N777UA
# 594749  2019-09-01          7                UA      N777UA
#
#         Flight_Number_Reporting_Airline Origin    OriginCityName  \
# 281057                               54    MIA         Miami, FL
# 284270                              291    JFK      New York, NY
# 284289                              291    JFK      New York, NY
# 284300                              291    MIA         Miami, FL
# 292835                             1496    PHL  Philadelphia, PA
# ...                                 ...    ...               ...
# 594074                             1101    IAH       Houston, TX
# 594325                              628    EWR        Newark, NJ
# 594435                              508    IAH       Houston, TX
# 594634                              313    DEN        Denver, CO
# 594749                              200    GUM          Guam, TT
#
#                                        OriginStateName  OriginCityMarketID  \
# 281057                                         Florida               32467
# 284270                                        New York               31703
# 284289                                        New York               31703
# 284300                                         Florida               32467
# 292835                                    Pennsylvania               34100
# ...                                                ...                 ...
# 594074                                           Texas               31453
# 594325                                      New Jersey               31703
# 594435                                           Texas               31453
# 594634                                        Colorado               30325
# 594749  U.S. Pacific Trust Territories and Possessions               32016
#
#        Dest       DestCityName DestStateName  DestCityMarketID  DepTime  \
# 281057  JFK       New York, NY      New York             31703    856.0
# 284270  MIA          Miami, FL       Florida             32467   1256.0
# 284289  MIA          Miami, FL       Florida             32467   1224.0
# 284300  JFK       New York, NY      New York             31703    853.0
# 292835  SJU       San Juan, PR   Puerto Rico             34819    802.0
# ...     ...                ...           ...               ...      ...
# 594074  DEN         Denver, CO      Colorado             30325   1012.0
# 594325  LAX    Los Angeles, CA    California             32575   2330.0
# 594435  SFO  San Francisco, CA    California             32457   1848.0
# 594634  IAH        Houston, TX         Texas             31453   1325.0
# 594749  HNL       Honolulu, HI        Hawaii             32134    707.0
#
#         DepDelay  AirTime  Distance
# 281057      21.0    145.0    1089.0
# 284270      -3.0    174.0    1089.0
# 284289      -5.0    132.0    1089.0
# 284300       3.0    159.0    1089.0
# 292835      -8.0    201.0    1576.0
# ...          ...      ...       ...
# 594074      -8.0    107.0     862.0
# 594325     210.0    304.0    2454.0
# 594435      -2.0    202.0    1635.0
# 594634      -5.0    108.0     862.0
# 594749      -3.0    410.0    3801.0
#
# [213 rows x 17 columns]

# %% [markdown]
# #### Exercise:
#
# Show cities by descending number of airports

# %%
df3.groupby('OriginCityName').nunique().sort_values(by='Origin',ascending=False)
# Out:
#                  FlightDate  DayOfWeek  Reporting_Airline  Tail_Number  \
# OriginCityName
# Houston, TX              30          7                 14         2666
# Washington, DC           30          7                 14         3066
# Chicago, IL              30          7                 13         3330
# New York, NY             30          7                 16         3097
# Mobile, AL               30          7                  8          263
# ...                     ...        ...                ...          ...
# Garden City, KS          30          7                  1           30
# Gainesville, FL          30          7                  5          232
# Fresno, CA               30          7                  6          357
# Fort Wayne, IN           30          7                  5          273
# Yuma, AZ                 30          7                  2           70
#
#                  Flight_Number_Reporting_Airline  Origin  OriginCityName  \
# OriginCityName
# Houston, TX                                 1315       2               1
# Washington, DC                               902       2               1
# Chicago, IL                                 2140       2               1
# New York, NY                                1233       2               1
# Mobile, AL                                    32       2               1
# ...                                          ...     ...             ...
# Garden City, KS                                2       1               1
# Gainesville, FL                               24       1               1
# Fresno, CA                                    46       1               1
# Fort Wayne, IN                                31       1               1
# Yuma, AZ                                      10       1               1
#
#                  OriginStateName  OriginCityMarketID  Dest  DestCityName  \
# OriginCityName
# Houston, TX                    1                   1   108           105
# Washington, DC                 1                   1   103           100
# Chicago, IL                    1                   1   173           170
# New York, NY                   1                   1    97            94
# Mobile, AL                     1                   1     6             6
# ...                          ...                 ...   ...           ...
# Garden City, KS                1                   1     1             1
# Gainesville, FL                1                   1     4             4
# Fresno, CA                     1                   1    11            11
# Fort Wayne, IN                 1                   1     9             9
# Yuma, AZ                       1                   1     2             2
#
#                  DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  \
# OriginCityName
# Houston, TX                 41                95     1132       337      271
# Washington, DC              41                93     1129       339      334
# Chicago, IL                 50               157     1166       416      337
# New York, NY                39                84     1173       345      380
# Mobile, AL                   5                 6      244        73       67
# ...                        ...               ...      ...       ...      ...
# Garden City, KS              1                 1       33        22       17
# Gainesville, FL              4                 4      237        74       51
# Fresno, CA                   9                11      458       124      146
# Fort Wayne, IN               7                 9      310       101       90
# Yuma, AZ                     2                 2      100        37       29
#
#                  Distance
# OriginCityName
# Houston, TX           146
# Washington, DC        145
# Chicago, IL           216
# New York, NY          131
# Mobile, AL              6
# ...                   ...
# Garden City, KS         1
# Gainesville, FL         4
# Fresno, CA             11
# Fort Wayne, IN          9
# Yuma, AZ                2
#
# [344 rows x 17 columns]

# %% [markdown]
# #### Exercise
#
# The list above doesn't correspond to our intuitive expectation, probably. That is because airports serving the same general area may be located within several different city limits. This is encapsulated by the "market" concept in commercial aviation.
#
# Find the 10 markets with the most airports, and which airports are included in them.

# %%
cities_airports=df3.groupby('OriginCityMarketID')['Origin','OriginCityName'].agg({'Origin':['nunique','unique'],'OriginCityName':['unique']})
cities_airports.sort_values(by=('OriginCityName','unique'),ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-231-a609843bf99d> in <module>
#       1 cities_airports=df3.groupby('OriginCityMarketID')['Origin','OriginCityName'].agg({'Origin':['nunique','unique'],'OriginCityName':['unique']})
# ----> 2 cities_airports.sort_values(by=('OriginCityName','unique'),ascending=False).head(10)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4997
#    4998             indexer = nargsort(
# -> 4999                 k, kind=kind, ascending=ascending, na_position=na_position
#    5000             )
#    5001
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position)
#     258         non_nans = non_nans[::-1]
#     259         non_nan_idx = non_nan_idx[::-1]
# --> 260     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     261     if not ascending:
#     262         indexer = indexer[::-1]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## Plotting
#
# There are several ways in which we could go about plotting this dataset in order to get acquainted with it.

# %% [markdown]
# For example, do the delays have a relationship with the number of departures a plane does?

# %% [markdown]
# #### Exercise
#
# Do a scatter plot of delays_by_plane with matplotlib, plotting mean delay versus number of departures. Check the documentation

# %%
delays_per_plane.plot.scatter('count','mean',alpha=.1)

# %%
ax = delays_per_plane.plot.hexbin('count','mean')
ax.set_xlim(-10,200)
ax.set_ylim(-10,50)
# Out:
# (-10, 50)

# %% [markdown]
# Pretty impossible to see anything in there. Maybe a different kind of plottting is required:

# %%
sns.jointplot(data=delays_per_plane,x='count',y='mean',kind='kde')

# %% [markdown]
# #### Exercise:
#
# Plot the distribution of delays as a histogram, both with a linear and a logarithmic scale

# %%
df3ax=df3['DepDelay'].plot.hist(bins=100,range=(-50,600))

# %%
ax=df3['DepDelay'].plot.hist(bins=100,range=(-50,600),log=True)

# %% [markdown]
# #### Exercise:
#
# How do the delays stack over the course of the day? We are going to look at it by plotting the distribution of delays for each hour of the day. The very best way to compare distributions side by side is a boxplot, so we'll use that.

# %% [markdown]
# We need to provide `plt.boxplot()` with a sequence that contains 24 elements. Each of those will be a sequence containing every individual delay for one hour of the day. We'll need, therefore, to extract hours of the day for each departure and group based on that.

# %%
df4=df3[df3['DepTime'].notna()]

# %%
df4['Hour']=df4['DepTime'].astype(str).str[:2]  #En este caso se quedan valores como 90 (las 9:00)
# Out:
# /home/joeldela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df4['Hour']=df4['DepTime'].astype(str).str.zfill(6).str[:2]     #Esta es una forma
df4['Hour']
# Out:
# /home/joeldela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 1         20
# 2         20
# 3         20
# 4         20
# 5         20
#           ..
# 605974    18
# 605975    18
# 605976    18
# 605977    18
# 605978    20
# Name: Hour, Length: 596198, dtype: object

# %%
df4['Hour']=df4['DepTime']//100              #Esta es otra forma
df4['Hour'].unique()
# Out:
# /home/joeldela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# array([20., 17., 21., 22., 19.,  6.,  8.,  7., 10., 11., 12., 13., 14.,
#        15., 16., 18., 23.,  5.,  4.,  9.,  0.,  1.,  2.,  3., 24.])

# %%
ax=sns.boxplot(data=df4,x='Hour',y='DepDelay')
ax.set_ylim(-20,250)
plt.gcf().set(size_inches=(18,8))
# Out:
# [None]

# %%
sns.jointplot(data=df4.sample(50000),x='Distance',y='AirTime',kind='kde')

# %% [markdown]
# #### Exercise
#
# We are also interested in examining how the home base influences delays. Do a boxplot of the delay distribution for the 10 airports with the most flights, and the 10 airports with the least flights.

# %%
flights_per_airport=df3.groupby('Origin')['Origin'].count()


bottom_top=pd.concat([flights_per_airport.sort_values(ascending=False).head(10), flights_per_airport.sort_values().head(10)])

# %%
filter = [origin in bottom_top for origin in df3['Origin']]

# %%
ax=sns.boxplot(data=df3[filter],x='Origin',y='DepDelay')
ax.set_ylim(-20,50)
plt.gcf().set_size_inches(14,8)

# %% [markdown]
# #### Take home project
#
# If we wanted to do some machine learning, we would need to create as many informative features as we thought could be useful. This is called Feature Engineering.
#
# Discrete data would most often be transformed by [one-hot encoding](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f), which is [very easy to do in pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html).
#
# ![One Hot Encoding](https://hackernoon.com/photos/4HK5qyMbWfetPhAavzyTZrEb90N2-3o23tie)
#
# With high cardinality discrete data such as airports or, especially, tail numbers, we would be left with many variables, most of which would not be very informative. There are [several options](https://www.datacamp.com/community/tutorials/encoding-methodologies) to deal with this. The most sophisticated is probably vector encoding, but we can do with a very simple approach: [target encoding](https://maxhalford.github.io/blog/target-encoding-done-the-right-way/).
#
# This means that we substitute each value of the discrete variable by the average or median value of the target variable for that value of the independent discrete variable. However! if we want to use this in machine learning for predictions, we would need to use only the previous values.
#
# Target encode the variable 'Origin' and the 'Tail_Number' variable, using for each cell only the values that were available the previous day. In other words: create a `median_delay_origin` variable that contains, for each record, the median delay at that airport _up to the previous day_. Create another one, `median_delay_plane`, with Tail_Number.
